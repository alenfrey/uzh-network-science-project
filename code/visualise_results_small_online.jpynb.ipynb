# %%
from lib import *
import pandas as pd
import seaborn as sns

# %%
all_online_networks = pd.read_csv(DATA_DIR_PATH / "online_social_networks.csv")
all_online_networks.head(2)
# Out:
#         group        name   nodes   edges  avg_degree  std_dev_degree  \
# 0      douban      douban  154908  327162        4.22           11.75
# 1  ego_social  facebook_0     333    2519       15.13           15.51
#
#    largest_eigenvalue_hashimoto  random_walk_mixing_time  \
# 0                         39.78                   103.63
# 1                         35.79                   172.26
#
#    degree_assortativity  global_clustering  diameter  \
# 0                 -0.18               0.01         9
# 1                  0.24               0.43        11
#
#    relative_size_of_largest_component        kind        mode  \
# 0                                1.00  Undirected  Unipartite
# 1                                0.97  Undirected  Unipartite
#
#        node_properties edge_properties  gml_file_size nodes_qcut
# 0                  NaN             NaN        3460300      large
# 1  name  feat  circles             NaN          22528      small

# %%
df = pd.read_csv("result_small_online.csv")
df = df.merge(all_online_networks, on="name")

# %%
pd.DataFrame(df.mean()).style.format("{:.2f}")
# Out:
# /var/folders/p9/02724x0n07j48t5y71my51980000gn/T/ipykernel_15564/2987761780.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pd.DataFrame(df.mean()).style.format("{:.2f}")
# <style type="text/css">
# </style>
# <table id="T_e689c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e689c_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e689c_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_e689c_row0_col0" class="data row0 col0" >28.00</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row1" class="row_heading level0 row1" >_</th>
#       <td id="T_e689c_row1_col0" class="data row1 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row2" class="row_heading level0 row2" >idx</th>
#       <td id="T_e689c_row2_col0" class="data row2 col0" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row3" class="row_heading level0 row3" >dataset</th>
#       <td id="T_e689c_row3_col0" class="data row3 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row4" class="row_heading level0 row4" >n_nodes</th>
#       <td id="T_e689c_row4_col0" class="data row4 col0" >290.11</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row5" class="row_heading level0 row5" >frac_total</th>
#       <td id="T_e689c_row5_col0" class="data row5 col0" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row6" class="row_heading level0 row6" >density</th>
#       <td id="T_e689c_row6_col0" class="data row6 col0" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row7" class="row_heading level0 row7" >dbar</th>
#       <td id="T_e689c_row7_col0" class="data row7 col0" >35.14</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row8" class="row_heading level0 row8" >dcv</th>
#       <td id="T_e689c_row8_col0" class="data row8 col0" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row9" class="row_heading level0 row9" >dmax</th>
#       <td id="T_e689c_row9_col0" class="data row9 col0" >176.19</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row10" class="row_heading level0 row10" >null_100_sim_g</th>
#       <td id="T_e689c_row10_col0" class="data row10 col0" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row11" class="row_heading level0 row11" >null_100_sim</th>
#       <td id="T_e689c_row11_col0" class="data row11 col0" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row12" class="row_heading level0 row12" >null_100_sim_e</th>
#       <td id="T_e689c_row12_col0" class="data row12 col0" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row13" class="row_heading level0 row13" >null_100_comp_g</th>
#       <td id="T_e689c_row13_col0" class="data row13 col0" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row14" class="row_heading level0 row14" >null_100_comp</th>
#       <td id="T_e689c_row14_col0" class="data row14 col0" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row15" class="row_heading level0 row15" >null_100_comp_e</th>
#       <td id="T_e689c_row15_col0" class="data row15 col0" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row16" class="row_heading level0 row16" >data_sim_g</th>
#       <td id="T_e689c_row16_col0" class="data row16 col0" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row17" class="row_heading level0 row17" >data_sim</th>
#       <td id="T_e689c_row17_col0" class="data row17 col0" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row18" class="row_heading level0 row18" >data_sim_e</th>
#       <td id="T_e689c_row18_col0" class="data row18 col0" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row19" class="row_heading level0 row19" >data_comp_g</th>
#       <td id="T_e689c_row19_col0" class="data row19 col0" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row20" class="row_heading level0 row20" >data_comp</th>
#       <td id="T_e689c_row20_col0" class="data row20 col0" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row21" class="row_heading level0 row21" >data_comp_e</th>
#       <td id="T_e689c_row21_col0" class="data row21 col0" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row22" class="row_heading level0 row22" >nodes</th>
#       <td id="T_e689c_row22_col0" class="data row22 col0" >292.37</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row23" class="row_heading level0 row23" >edges</th>
#       <td id="T_e689c_row23_col0" class="data row23 col0" >6605.35</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row24" class="row_heading level0 row24" >avg_degree</th>
#       <td id="T_e689c_row24_col0" class="data row24 col0" >35.00</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row25" class="row_heading level0 row25" >std_dev_degree</th>
#       <td id="T_e689c_row25_col0" class="data row25 col0" >31.52</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row26" class="row_heading level0 row26" >largest_eigenvalue_hashimoto</th>
#       <td id="T_e689c_row26_col0" class="data row26 col0" >59.64</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row27" class="row_heading level0 row27" >random_walk_mixing_time</th>
#       <td id="T_e689c_row27_col0" class="data row27 col0" >16.35</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row28" class="row_heading level0 row28" >degree_assortativity</th>
#       <td id="T_e689c_row28_col0" class="data row28 col0" >-0.19</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row29" class="row_heading level0 row29" >global_clustering</th>
#       <td id="T_e689c_row29_col0" class="data row29 col0" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row30" class="row_heading level0 row30" >diameter</th>
#       <td id="T_e689c_row30_col0" class="data row30 col0" >5.21</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row31" class="row_heading level0 row31" >relative_size_of_largest_component</th>
#       <td id="T_e689c_row31_col0" class="data row31 col0" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_e689c_level0_row32" class="row_heading level0 row32" >gml_file_size</th>
#       <td id="T_e689c_row32_col0" class="data row32 col0" >32298.77</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.DataFrame(df.std()).style.format("{:.2f}")
# Out:
# /var/folders/p9/02724x0n07j48t5y71my51980000gn/T/ipykernel_15564/2672538562.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pd.DataFrame(df.std()).style.format("{:.2f}")
# <style type="text/css">
# </style>
# <table id="T_11c97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11c97_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11c97_level0_row0" class="row_heading level0 row0" >Unnamed: 0</th>
#       <td id="T_11c97_row0_col0" class="data row0 col0" >16.60</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row1" class="row_heading level0 row1" >_</th>
#       <td id="T_11c97_row1_col0" class="data row1 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row2" class="row_heading level0 row2" >idx</th>
#       <td id="T_11c97_row2_col0" class="data row2 col0" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row3" class="row_heading level0 row3" >dataset</th>
#       <td id="T_11c97_row3_col0" class="data row3 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row4" class="row_heading level0 row4" >n_nodes</th>
#       <td id="T_11c97_row4_col0" class="data row4 col0" >187.53</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row5" class="row_heading level0 row5" >frac_total</th>
#       <td id="T_11c97_row5_col0" class="data row5 col0" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row6" class="row_heading level0 row6" >density</th>
#       <td id="T_11c97_row6_col0" class="data row6 col0" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row7" class="row_heading level0 row7" >dbar</th>
#       <td id="T_11c97_row7_col0" class="data row7 col0" >28.30</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row8" class="row_heading level0 row8" >dcv</th>
#       <td id="T_11c97_row8_col0" class="data row8 col0" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row9" class="row_heading level0 row9" >dmax</th>
#       <td id="T_11c97_row9_col0" class="data row9 col0" >136.43</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row10" class="row_heading level0 row10" >null_100_sim_g</th>
#       <td id="T_11c97_row10_col0" class="data row10 col0" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row11" class="row_heading level0 row11" >null_100_sim</th>
#       <td id="T_11c97_row11_col0" class="data row11 col0" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row12" class="row_heading level0 row12" >null_100_sim_e</th>
#       <td id="T_11c97_row12_col0" class="data row12 col0" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row13" class="row_heading level0 row13" >null_100_comp_g</th>
#       <td id="T_11c97_row13_col0" class="data row13 col0" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row14" class="row_heading level0 row14" >null_100_comp</th>
#       <td id="T_11c97_row14_col0" class="data row14 col0" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row15" class="row_heading level0 row15" >null_100_comp_e</th>
#       <td id="T_11c97_row15_col0" class="data row15 col0" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row16" class="row_heading level0 row16" >data_sim_g</th>
#       <td id="T_11c97_row16_col0" class="data row16 col0" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row17" class="row_heading level0 row17" >data_sim</th>
#       <td id="T_11c97_row17_col0" class="data row17 col0" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row18" class="row_heading level0 row18" >data_sim_e</th>
#       <td id="T_11c97_row18_col0" class="data row18 col0" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row19" class="row_heading level0 row19" >data_comp_g</th>
#       <td id="T_11c97_row19_col0" class="data row19 col0" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row20" class="row_heading level0 row20" >data_comp</th>
#       <td id="T_11c97_row20_col0" class="data row20 col0" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row21" class="row_heading level0 row21" >data_comp_e</th>
#       <td id="T_11c97_row21_col0" class="data row21 col0" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row22" class="row_heading level0 row22" >nodes</th>
#       <td id="T_11c97_row22_col0" class="data row22 col0" >187.06</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row23" class="row_heading level0 row23" >edges</th>
#       <td id="T_11c97_row23_col0" class="data row23 col0" >7634.54</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row24" class="row_heading level0 row24" >avg_degree</th>
#       <td id="T_11c97_row24_col0" class="data row24 col0" >28.32</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row25" class="row_heading level0 row25" >std_dev_degree</th>
#       <td id="T_11c97_row25_col0" class="data row25 col0" >24.28</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row26" class="row_heading level0 row26" >largest_eigenvalue_hashimoto</th>
#       <td id="T_11c97_row26_col0" class="data row26 col0" >44.63</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row27" class="row_heading level0 row27" >random_walk_mixing_time</th>
#       <td id="T_11c97_row27_col0" class="data row27 col0" >41.08</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row28" class="row_heading level0 row28" >degree_assortativity</th>
#       <td id="T_11c97_row28_col0" class="data row28 col0" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row29" class="row_heading level0 row29" >global_clustering</th>
#       <td id="T_11c97_row29_col0" class="data row29 col0" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row30" class="row_heading level0 row30" >diameter</th>
#       <td id="T_11c97_row30_col0" class="data row30 col0" >1.80</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row31" class="row_heading level0 row31" >relative_size_of_largest_component</th>
#       <td id="T_11c97_row31_col0" class="data row31 col0" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_11c97_level0_row32" class="row_heading level0 row32" >gml_file_size</th>
#       <td id="T_11c97_row32_col0" class="data row32 col0" >30013.81</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_', 'idx', 'dataset', 'name', 'n_nodes', 'frac_total',
#        'density', 'dbar', 'dcv', 'dmax', 'null_100_sim_g', 'null_100_sim',
#        'null_100_sim_e', 'null_100_comp_g', 'null_100_comp', 'null_100_comp_e',
#        'data_sim_g', 'data_sim', 'data_sim_e', 'data_comp_g', 'data_comp',
#        'data_comp_e', 'group', 'nodes', 'edges', 'avg_degree',
#        'std_dev_degree', 'largest_eigenvalue_hashimoto',
#        'random_walk_mixing_time', 'degree_assortativity', 'global_clustering',
#        'diameter', 'relative_size_of_largest_component', 'kind', 'mode',
#        'node_properties', 'edge_properties', 'gml_file_size', 'nodes_qcut'],
#       dtype='object')

# %%
len(df.index)
# Out:
# 57

# %%
df.head(3)
# Out:
#    Unnamed: 0  _  idx  dataset              name  n_nodes  frac_total  \
# 0           0  0    1      NaN                S2      165     1.00000
# 1           1  0    1      NaN                S1      320     1.00000
# 2           2  0    1      NaN  facebook_friends      329     0.90884
#
#     density       dbar       dcv  ...  degree_assortativity  \
# 0  0.053659   8.800000  0.946063  ...                 -0.07
# 1  0.046415  14.806250  0.963127  ...                 -0.02
# 2  0.036215  11.878419  0.921316  ...                  0.10
#
#    global_clustering  diameter  relative_size_of_largest_component  \
# 0               0.33         6                                1.00
# 1               0.29         7                                1.00
# 2               0.51         9                                0.91
#
#          kind        mode                             node_properties  \
# 0  Undirected  Unipartite                                        name
# 1  Undirected  Unipartite                                        name
# 2  Undirected  Unipartite  context_0  context_1  context_2  context_3
#
#    edge_properties  gml_file_size  nodes_qcut
# 0              NaN           6144       small
# 1              NaN          14336       small
# 2             name          17408       small
#
# [3 rows x 40 columns]

# %%
def plot_correlation_matrix(df, title):
    plt.figure(figsize=(8, 8))
    plt.title(title)
    mask = np.triu(np.ones_like(df, dtype=bool))
    sns.heatmap(df, annot=True, fmt=".2f", mask=mask, cmap="coolwarm")
    plt.show()

# %%
plot_correlation_matrix(df[["n_nodes", "density", "degree_assortativity", "dbar", "dcv", "dmax", "data_sim_g", "data_comp_g"]].corr(), \"Correlations of (Astructural) measures in large Online networks\")
# Out:
#   Cell In[35], line 1
#     plot_correlation_matrix(df[["n_nodes", "density", "degree_assortativity", "dbar", "dcv", "dmax", "data_sim_g", "data_comp_g"]].corr(), \"Correlations of (Astructural) measures in large Online networks\")
#                                                                                                                                             ^
# SyntaxError: unexpected character after line continuation character

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_', 'idx', 'dataset', 'name', 'n_nodes', 'frac_total',
#        'density', 'dbar', 'dcv', 'dmax', 'null_100_sim_g', 'null_100_sim',
#        'null_100_sim_e', 'null_100_comp_g', 'null_100_comp', 'null_100_comp_e',
#        'data_sim_g', 'data_sim', 'data_sim_e', 'data_comp_g', 'data_comp',
#        'data_comp_e', 'group', 'nodes', 'edges', 'avg_degree',
#        'std_dev_degree', 'largest_eigenvalue_hashimoto',
#        'random_walk_mixing_time', 'degree_assortativity', 'global_clustering',
#        'diameter', 'relative_size_of_largest_component', 'kind', 'mode',
#        'node_properties', 'edge_properties', 'gml_file_size', 'nodes_qcut'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="data_comp_g", y="null_10_comp_g")
plt.title("Global complementarity of small online networks, data vs. null model")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.scatterplot(data=df, x="data_comp_g", y="null_10_comp_g")
#       2 plt.title("Global complementarity of small online networks, data vs. null model")
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/relational.py:808, in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     793 @_deprecate_positional_args
#     794 def scatterplot(
#     795     *,
#    (...)
#     804     legend="auto", ax=None, **kwargs
#     805 ):
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#     811         estimator=estimator, ci=ci, n_boot=n_boot,
#     812         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     813     )
#     815     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     816     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/relational.py:587, in _ScatterPlotter.__init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     571 def __init__(
#     572     self, *,
#     573     data=None, variables={},
#    (...)
#     581     # the kind of plot to draw, but for the time being we need to set
#     582     # this information so the SizeMapping can use it
#     583     self._default_size_range = (
#     584         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     585     )
# --> 587     super().__init__(data=data, variables=variables)
#     589     self.alpha = alpha
#     590     self.legend = legend
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_core.py:903, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     898 elif isinstance(val, (str, bytes)):
#     899
#     900     # This looks like a column name but we don't know what it means!
#     902     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903     raise ValueError(err)
#     905 else:
#     906
#     907     # Otherwise, assume the value is itself data
#     908
#     909     # Raise when data object is present and a vector can't matched
#     910     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `null_10_comp_g` for parameter `y`

# %%
sns.scatterplot(data=df, x="degree_assortativity", y="data_comp_g")
plt.title("Global complementarity of small online networks, data vs. null model")
# Out:
# Text(0.5, 1.0, 'Global complementarity of small online networks, data vs. null model')

# %%
sns.scatterplot(data=df, x="data_sim_g", y="data_comp_g")
plt.title("Similarity vs. complementarity of small online networks, data")
# Out:
# Text(0.5, 1.0, 'Similarity vs. complementarity of small online networks, data')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '_', 'idx', 'dataset', 'name', 'n_nodes', 'frac_total',
#        'density', 'dbar', 'dcv', 'dmax', 'null_100_sim_g', 'null_100_sim',
#        'null_100_sim_e', 'null_100_comp_g', 'null_100_comp', 'null_100_comp_e',
#        'data_sim_g', 'data_sim', 'data_sim_e', 'data_comp_g', 'data_comp',
#        'data_comp_e', 'group', 'nodes', 'edges', 'avg_degree',
#        'std_dev_degree', 'largest_eigenvalue_hashimoto',
#        'random_walk_mixing_time', 'degree_assortativity', 'global_clustering',
#        'diameter', 'relative_size_of_largest_component', 'kind', 'mode',
#        'node_properties', 'edge_properties', 'gml_file_size', 'nodes_qcut'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="data_comp_g", y="null_10_comp_g")
plt.title("Global complementarity of large online networks, data vs. null model")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sns.scatterplot(data=df, x="data_comp_g", y="null_10_comp_g")
#       2 plt.title("Global complementarity of large online networks, data vs. null model")
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/relational.py:808, in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     793 @_deprecate_positional_args
#     794 def scatterplot(
#     795     *,
#    (...)
#     804     legend="auto", ax=None, **kwargs
#     805 ):
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#     811         estimator=estimator, ci=ci, n_boot=n_boot,
#     812         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     813     )
#     815     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     816     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/relational.py:587, in _ScatterPlotter.__init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     571 def __init__(
#     572     self, *,
#     573     data=None, variables={},
#    (...)
#     581     # the kind of plot to draw, but for the time being we need to set
#     582     # this information so the SizeMapping can use it
#     583     self._default_size_range = (
#     584         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     585     )
# --> 587     super().__init__(data=data, variables=variables)
#     589     self.alpha = alpha
#     590     self.legend = legend
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/_core.py:903, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     898 elif isinstance(val, (str, bytes)):
#     899
#     900     # This looks like a column name but we don't know what it means!
#     902     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903     raise ValueError(err)
#     905 else:
#     906
#     907     # Otherwise, assume the value is itself data
#     908
#     909     # Raise when data object is present and a vector can't matched
#     910     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `null_10_comp_g` for parameter `y`

# %%
sns.boxplot(data=df[["data_comp_g", "data_sim_g"]], orient="h", palette="Paired")
plt.title("Global complementarity and global similarity of small online networks")
# Out:
# /Users/keisuke/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# Text(0.5, 1.0, 'Global complementarity and global similarity of small online networks')

# %%
df[df["data_sim_g"] < 0.1]
# Out:
#     Unnamed: 0  _  idx  dataset                         name  n_nodes  \
# 31          31  0    1      NaN  gplus_104076158580173410325        8
# 43          43  0    1      NaN  gplus_110581012109008817546      627
#
#     frac_total   density     dbar       dcv  ...  degree_assortativity  \
# 31         1.0  0.250000  1.75000  1.133893  ...                 -1.00
# 43         1.0  0.010563  6.61244  3.801860  ...                 -0.56
#
#     global_clustering  diameter  relative_size_of_largest_component  \
# 31               0.00         2                                 1.0
# 43               0.05         4                                 1.0
#
#           kind        mode      node_properties  edge_properties  \
# 31  Undirected   Bipartite  name  feat  circles              NaN
# 43  Undirected  Unipartite  name  feat  circles              NaN
#
#     gml_file_size  nodes_qcut
# 31            902       small
# 43          26624       small
#
# [2 rows x 40 columns]

# %%
df[df["data_sim_g"] > 0.35]
# Out:
#     Unnamed: 0  _  idx  dataset                         name  n_nodes  \
# 2            2  0    1      NaN             facebook_friends      329
# 3            3  0    1      NaN  gplus_114054672576929802335      175
# 4            4  0    1      NaN  gplus_116899029375914044550       22
# 5            5  0    1      NaN                facebook_3980       44
# 7            7  0    1      NaN                 facebook_348      224
# 9            9  0    1      NaN  gplus_110241952466097562819       83
# 10          10  0    1      NaN  gplus_113597493946570654755      321
# 11          11  0    1      NaN  gplus_101541879642294398860      486
# 14          14  0    1      NaN  gplus_107965826228461029730      495
# 15          15  0    1      NaN                 facebook_414      148
# 16          16  0    1      NaN  gplus_102615863344410467759      102
# 17          17  0    1      NaN  gplus_115576988435396060952      492
# 18          18  0    1      NaN  gplus_109342148209917802565      550
# 20          20  0    1      NaN                 facebook_698       40
# 21          21  0    1      NaN  gplus_118255645714452180374      215
# 22          22  0    1      NaN  gplus_101499880233887429402      268
# 23          23  0    1      NaN  gplus_103241736833663734962      131
# 24          24  0    1      NaN  gplus_100466178325794757407      342
# 25          25  0    1      NaN  gplus_111213696402662884531      258
# 27          27  0    1      NaN  gplus_100521671383026672718      521
# 28          28  0    1      NaN  gplus_110614416163543421878      338
# 29          29  0    1      NaN                 facebook_686      168
# 30          30  0    1      NaN  gplus_101997124338642780860      575
# 32          32  0    1      NaN  gplus_114104634069486127920      320
# 33          33  0    1      NaN  gplus_103503116383846951534      422
# 34          34  0    1      NaN  gplus_100637660947564674695      296
# 35          35  0    1      NaN  gplus_117503822947457399073      301
# 36          36  0    1      NaN  gplus_100962871525684315897      559
# 37          37  0    1      NaN  gplus_104672614700283598130      475
# 38          38  0    1      NaN  gplus_110739220927723360152       54
# 40          40  0    1      NaN  gplus_113455290791279442483      108
# 41          41  0    1      NaN  gplus_106328207304735502636       35
# 42          42  0    1      NaN  gplus_101560853443212199687       19
# 46          46  0    1      NaN  gplus_116450966137824114154       92
# 49          49  0    1      NaN  gplus_117866881767579360121      117
# 50          50  0    1      NaN  gplus_112737356589974073749      474
# 51          51  0    1      NaN                   facebook_0      324
# 52          52  0    1      NaN  gplus_101848191156408080085       94
# 53          53  0    1      NaN  gplus_110232479818136355682      116
# 54          54  0    1      NaN  gplus_115360471097759949621      511
# 55          55  0    1      NaN                facebook_3437      532
# 56          56  0    1      NaN  gplus_100518419853963396365      326
#
#     frac_total   density        dbar       dcv  ...  degree_assortativity  \
# 2     0.908840  0.036215   11.878419  0.921316  ...                  0.10
# 3     1.000000  0.271790   47.291429  0.802294  ...                 -0.39
# 4     1.000000  0.467532    9.818182  0.578315  ...                 -0.54
# 5     0.846154  0.145877    6.272727  0.662875  ...                  0.16
# 7     1.000000  0.127803   28.500000  0.784823  ...                  0.22
# 9     1.000000  0.197179   16.168675  0.957174  ...                 -0.51
# 10    1.000000  0.144100   46.112150  0.878640  ...                 -0.06
# 11    0.995902  0.128658   62.399177  0.988380  ...                 -0.24
# 14    1.000000  0.137038   67.696970  0.895123  ...                 -0.24
# 15    0.986667  0.155543   22.864865  0.564535  ...                  0.31
# 16    1.000000  0.226946   22.921569  0.776149  ...                 -0.36
# 17    1.000000  0.097470   47.857724  1.021605  ...                 -0.21
# 18    1.000000  0.105243   57.778182  1.020319  ...                 -0.18
# 20    0.655738  0.282051   11.000000  0.521441  ...                  0.29
# 21    1.000000  0.269028   57.572093  0.704316  ...                 -0.29
# 22    1.000000  0.150875   40.283582  1.108062  ...                 -0.46
# 23    1.000000  0.157604   20.488550  0.787310  ...                 -0.09
# 24    0.994186  0.057639   19.654971  1.022864  ...                  0.14
# 25    1.000000  0.229964   59.100775  0.767307  ...                 -0.20
# 27    1.000000  0.122235   63.562380  1.164263  ...                 -0.41
# 28    1.000000  0.186575   62.875740  0.716195  ...                 -0.18
# 29    1.000000  0.118050   19.714286  0.812653  ...                  0.08
# 30    1.000000  0.069486   39.885217  1.212853  ...                 -0.16
# 32    1.000000  0.169808   54.168750  0.712471  ...                 -0.03
# 33    1.000000  0.064685   27.232227  0.962845  ...                  0.06
# 34    1.000000  0.072881   21.500000  0.890091  ...                 -0.17
# 35    0.980456  0.249812   74.943522  0.719168  ...                 -0.18
# 36    1.000000  0.171549   95.724508  0.949490  ...                 -0.24
# 37    1.000000  0.162878   77.204211  0.751669  ...                 -0.19
# 38    1.000000  0.141859    7.518519  0.781747  ...                  0.07
# 40    1.000000  0.407061   43.555556  0.527435  ...                 -0.24
# 41    1.000000  0.342857   11.657143  0.439307  ...                  0.06
# 42    1.000000  0.549708    9.894737  0.469353  ...                 -0.55
# 46    1.000000  0.199952   18.195652  0.879265  ...                 -0.36
# 49    1.000000  0.106101   12.307692  1.107056  ...                 -0.38
# 50    0.995798  0.241425  114.194093  0.684912  ...                 -0.19
# 51    0.972973  0.048045   15.518519  1.001830  ...                  0.24
# 52    1.000000  0.229925   21.382979  0.786347  ...                 -0.25
# 53    0.966667  0.153523   17.655172  0.843995  ...                 -0.03
# 54    1.000000  0.268700  137.037182  0.819217  ...                 -0.47
# 55    0.996255  0.034068   18.090226  0.809888  ...                  0.22
# 56    1.000000  0.154412   50.184049  0.816753  ...                 -0.04
#
#     global_clustering  diameter  relative_size_of_largest_component  \
# 2                0.51         9                                0.91
# 3                0.54         5                                1.00
# 4                0.62         3                                1.00
# 5                0.45         5                                0.85
# 7                0.49         9                                1.00
# 9                0.45         4                                1.00
# 10               0.45         5                                1.00
# 11               0.39         5                                1.00
# 14               0.41         4                                1.00
# 15               0.65         7                                0.99
# 16               0.42         3                                1.00
# 17               0.37         7                                1.00
# 18               0.37         5                                1.00
# 20               0.66         4                                0.66
# 21               0.51         4                                1.00
# 22               0.35         5                                1.00
# 23               0.44         5                                1.00
# 24               0.45         6                                0.99
# 25               0.51         4                                1.00
# 27               0.39         4                                1.00
# 28               0.45         7                                1.00
# 29               0.45         6                                1.00
# 30               0.39         7                                1.00
# 32               0.46         4                                1.00
# 33               0.36         6                                1.00
# 34               0.41         6                                1.00
# 35               0.53         7                                0.98
# 36               0.55         6                                1.00
# 37               0.42         5                                1.00
# 38               0.44         5                                1.00
# 40               0.60         3                                1.00
# 41               0.63         3                                1.00
# 42               0.62         2                                1.00
# 46               0.43         5                                1.00
# 49               0.39         5                                1.00
# 50               0.48         4                                1.00
# 51               0.43        11                                0.97
# 52               0.52         5                                1.00
# 53               0.47         5                                0.97
# 54               0.44         2                                1.00
# 55               0.45         9                                1.00
# 56               0.46         4                                1.00
#
#           kind        mode                             node_properties  \
# 2   Undirected  Unipartite  context_0  context_1  context_2  context_3
# 3   Undirected  Unipartite                         name  feat  circles
# 4   Undirected  Unipartite                         name  feat  circles
# 5   Undirected  Unipartite                         name  feat  circles
# 7   Undirected  Unipartite                         name  feat  circles
# 9   Undirected  Unipartite                         name  feat  circles
# 10  Undirected  Unipartite                         name  feat  circles
# 11  Undirected  Unipartite                         name  feat  circles
# 14  Undirected  Unipartite                         name  feat  circles
# 15  Undirected  Unipartite                         name  feat  circles
# 16  Undirected  Unipartite                         name  feat  circles
# 17  Undirected  Unipartite                         name  feat  circles
# 18  Undirected  Unipartite                         name  feat  circles
# 20  Undirected  Unipartite                         name  feat  circles
# 21  Undirected  Unipartite                         name  feat  circles
# 22  Undirected  Unipartite                         name  feat  circles
# 23  Undirected  Unipartite                         name  feat  circles
# 24  Undirected  Unipartite                         name  feat  circles
# 25  Undirected  Unipartite                         name  feat  circles
# 27  Undirected  Unipartite                         name  feat  circles
# 28  Undirected  Unipartite                         name  feat  circles
# 29  Undirected  Unipartite                         name  feat  circles
# 30  Undirected  Unipartite                         name  feat  circles
# 32  Undirected  Unipartite                         name  feat  circles
# 33  Undirected  Unipartite                         name  feat  circles
# 34  Undirected  Unipartite                         name  feat  circles
# 35  Undirected  Unipartite                         name  feat  circles
# 36  Undirected  Unipartite                         name  feat  circles
# 37  Undirected  Unipartite                         name  feat  circles
# 38  Undirected  Unipartite                         name  feat  circles
# 40  Undirected  Unipartite                         name  feat  circles
# 41  Undirected  Unipartite                         name  feat  circles
# 42  Undirected  Unipartite                         name  feat  circles
# 46  Undirected  Unipartite                         name  feat  circles
# 49  Undirected  Unipartite                         name  feat  circles
# 50  Undirected  Unipartite                         name  feat  circles
# 51  Undirected  Unipartite                         name  feat  circles
# 52  Undirected  Unipartite                         name  feat  circles
# 53  Undirected  Unipartite                         name  feat  circles
# 54  Undirected  Unipartite                         name  feat  circles
# 55  Undirected  Unipartite                         name  feat  circles
# 56  Undirected  Unipartite                         name  feat  circles
#
#     edge_properties  gml_file_size  nodes_qcut
# 2              name          17408       small
# 3               NaN          20480       small
# 4               NaN           1024       small
# 5               NaN           3072       small
# 7               NaN          19456       small
# 9               NaN           5120       small
# 10              NaN          36864       small
# 11              NaN          70656       small
# 14              NaN          76800       small
# 15              NaN          11264       small
# 16              NaN           8192       small
# 17              NaN          55296       small
# 18              NaN          71680       small
# 20              NaN           4096       small
# 21              NaN          27648       small
# 22              NaN          27648       small
# 23              NaN          10240       small
# 24              NaN          23552       small
# 25              NaN          32768       small
# 27              NaN          73728       small
# 28              NaN          48128       small
# 29              NaN          11264       small
# 30              NaN          58368       small
# 32              NaN          39936       small
# 33              NaN          35840       small
# 34              NaN          21504       small
# 35              NaN          47104       small
# 36              NaN         105472       small
# 37              NaN          79872       small
# 38              NaN           3072       small
# 40              NaN          11264       small
# 41              NaN           2048       small
# 42              NaN           1024       small
# 46              NaN           6144       small
# 49              NaN           6144       small
# 50              NaN         101376       small
# 51              NaN          22528       small
# 52              NaN           7168       small
# 53              NaN           9216       small
# 54              NaN         129024       small
# 55              NaN          34816       small
# 56              NaN          39936       small
#
# [42 rows x 40 columns]

# %%
df[df["data_sim_g"] < df["data_comp_g"]]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, _, idx, dataset, name, n_nodes, frac_total, density, dbar, dcv, dmax, null_100_sim_g, null_100_sim, null_100_sim_e, null_100_comp_g, null_100_comp, null_100_comp_e, data_sim_g, data_sim, data_sim_e, data_comp_g, data_comp, data_comp_e, group, nodes, edges, avg_degree, std_dev_degree, largest_eigenvalue_hashimoto, random_walk_mixing_time, degree_assortativity, global_clustering, diameter, relative_size_of_largest_component, kind, mode, node_properties, edge_properties, gml_file_size, nodes_qcut]
# Index: []
#
# [0 rows x 40 columns]

# %%
sns.boxplot(data=df[["null_10_comp_g", "null_10_sim_g"]], orient="h", palette="Paired")
plt.title("Global complementarity and global similarity of large online networks, null models")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.boxplot(data=df[["null_10_comp_g", "null_10_sim_g"]], orient="h", palette="Paired")
#       2 plt.title("Global complementarity and global similarity of large online networks, null models")
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/Network_Science/lib/python3.10/site-packages/pandas/core/indexes/base.py:6173, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     if use_interval_msg:
#    6172         key = list(key)
# -> 6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['null_10_comp_g', 'null_10_sim_g'], dtype='object')] are in the [columns]"

# %%
df["data_sim_g"].hist(density=True, bins=10)
plt.title("Global similarity of small online networks")
plt.xlabel("Global similarity coefficient")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %%
df["data_comp_g"].hist(density=True, bins=10)
plt.title("Global complementarity of small online networks")
plt.xlabel("Global complementarity coefficient")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')
