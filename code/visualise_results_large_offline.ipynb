# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data/structural_measures_large_offline.csv")

# %%
all_offline_networks = pd.read_csv("data/offline_social_networks.csv")
df = df.merge(all_offline_networks, on = "name")
df.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0  _  idx  dataset              name  n_nodes  frac_total  \
# 0            0  0    1      NaN           contact      274    1.000000
# 1            0  0    1      NaN           contact      274    1.000000
# 2            0  0    1      NaN        fb_friends      800    1.000000
# 3            0  0    1      NaN        fb_friends      800    1.000000
# 4            0  0    1      NaN             crime     1263    0.915217
# 5            0  0    1      NaN             crime     1263    0.915217
# 6            0  0    1      NaN            InVS15      219    0.943966
# 7            0  0    1      NaN            InVS15      219    0.943966
# 8            0  0    1      NaN              SFHH      403    1.000000
# 9            0  0    1      NaN              SFHH      403    1.000000
# 10           0  0    1      NaN          facebook      156    0.474164
# 11           0  0    1      NaN          facebook      156    0.474164
# 12           0  0    1      NaN         proximity      327    0.993921
# 13           0  0    1      NaN         proximity      327    0.993921
# 14           0  0    1      NaN     friendship-11      250    1.000000
# 15           0  0    1      NaN     friendship-12      229    1.000000
# 16           0  0    1      NaN     friendship-16      372    1.000000
# 17           0  0    1      NaN      friendship-4      320    1.000000
# 18           0  0    1      NaN      friendship-8      369    1.000000
# 19           0  0    1      NaN  health-advice_11      234    0.975000
# 20           0  0    1      NaN  health-advice_16      349    0.997143
# 21           0  0    1      NaN   health-advice_4      316    1.000000
# 22           0  0    1      NaN   health-advice_8      361    1.000000
#
#      density        dbar       dcv  ...  degree_assortativity  \
# 0   0.056790   15.503650  1.629853  ...                 -0.05
# 1   0.056790   15.503650  1.629853  ...                 -0.05
# 2   0.020081   16.045000  0.834117  ...                  0.18
# 3   0.020081   16.045000  0.834117  ...                  0.18
# 4   0.001728    2.180523  1.002800  ...                 -0.17
# 5   0.001728    2.180523  1.002800  ...                 -0.17
# 6   0.700641  152.739726  0.242809  ...                  0.26
# 7   0.700641  152.739726  0.242809  ...                  0.26
# 8   0.908077  365.047146  0.137335  ...                  0.11
# 9   0.908077  365.047146  0.137335  ...                  0.11
# 10  0.118859   18.423077  0.523348  ...                  0.02
# 11  0.118859   18.423077  0.523348  ...                  0.02
# 12  0.109154   35.584098  0.379312  ...                  0.47
# 13  0.109154   35.584098  0.379312  ...                  0.47
# 14  0.034153    8.504000  0.700219  ...                 -0.12
# 15  0.033402    7.615721  0.856621  ...                 -0.06
# 16  0.019882    7.376344  0.716235  ...                 -0.04
# 17  0.040674   12.975000  0.656773  ...                 -0.09
# 18  0.025819    9.501355  0.703625  ...                 -0.04
# 19  0.019332    4.504274  1.666350  ...                 -0.21
# 20  0.014195    4.939828  2.205252  ...                 -0.20
# 21  0.020997    6.613924  0.962691  ...                 -0.10
# 22  0.019037    6.853186  1.044779  ...                 -0.14
#
#     global_clustering  diameter  relative_size_of_largest_component  \
# 0                0.90         4                                1.00
# 1                0.90         4                                1.00
# 2                0.24         7                                1.00
# 3                0.24         7                                1.00
# 4                0.00        32                                0.92
# 5                0.00        32                                0.92
# 6                0.88         3                                0.94
# 7                0.88         3                                0.94
# 8                0.97         2                                1.00
# 9                0.97         2                                1.00
# 10               0.52         5                                0.47
# 11               0.52         5                                0.47
# 12               0.61         4                                0.99
# 13               0.61         4                                0.99
# 14               0.10         5                                1.00
# 15               0.09         6                                1.00
# 16               0.06         7                                1.00
# 17               0.09         5                                1.00
# 18               0.06         5                                1.00
# 19               0.05         8                                0.97
# 20               0.05         7                                1.00
# 21               0.05         6                                1.00
# 22               0.05         7                                1.00
#
#           kind        mode    node_properties  edge_properties  gml_file_size  \
# 0   Undirected  Unipartite                NaN     weight  time         153600
# 1   Undirected  Unipartite                NaN     weight  time         153600
# 2   Undirected  Unipartite         id  female              NaN          36864
# 3   Undirected  Unipartite         id  female              NaN          36864
# 4   Undirected   Bipartite               meta              NaN          35840
# 5   Undirected   Bipartite               meta              NaN          35840
# 6   Undirected  Unipartite          id  group             time        3879731
# 7   Undirected  Unipartite          id  group             time        3879731
# 8   Undirected  Unipartite          id  group             time        4194304
# 9   Undirected  Unipartite          id  group             time        4194304
# 10  Undirected  Unipartite  id  class  gender              NaN          13312
# 11  Undirected  Unipartite  id  class  gender              NaN          13312
# 12  Undirected  Unipartite  id  class  gender             time         588800
# 13  Undirected  Unipartite  id  class  gender             time         588800
# 14  Undirected  Unipartite               name              NaN          15360
# 15  Undirected  Unipartite               name              NaN          13312
# 16  Undirected  Unipartite               name              NaN          20480
# 17  Undirected  Unipartite               name              NaN          21504
# 18  Undirected  Unipartite               name              NaN          22528
# 19  Undirected  Unipartite               name              NaN          12288
# 20  Undirected  Unipartite               name              NaN          18432
# 21  Undirected  Unipartite               name              NaN          17408
# 22  Undirected  Unipartite               name              NaN          20480
#
#     nodes_qcut
# 0        large
# 1        large
# 2        large
# 3        large
# 4        large
# 5        large
# 6        large
# 7        large
# 8        large
# 9        large
# 10       large
# 11       large
# 12       large
# 13       large
# 14       large
# 15       large
# 16       large
# 17       large
# 18       large
# 19       large
# 20       large
# 21       large
# 22       large
#
# [23 rows x 40 columns]>

# %%
df.to_csv("vis_large_offline.csv")

# %%
def plot_correlation_matrix(df, title):
    plt.figure(figsize=(8, 8))
    plt.title(title)
    mask = np.triu(np.ones_like(df, dtype=bool))
    sns.heatmap(df, annot=True, fmt=".2f", mask=mask, cmap="coolwarm")
    plt.show()

# %%
plot_correlation_matrix(df[["n_nodes", "density", "degree_assortativity", "dbar", "dcv", "dmax", "data_sim_g", "data_comp_g"]].corr(), "Correlations of (Astructural) measures in large Online networks")

# %%
sns.scatterplot(data=df, x="degree_assortativity", y="data_comp_g")
plt.title("Global complementarity of large offline networks, data vs. null model")
# Out:
# Text(0.5, 1.0, 'Global complementarity of large offline networks, data vs. null model')

# %%
sns.scatterplot(data=df, x="data_sim_g", y="data_comp_g")
plt.title("Similarity vs. complementarity of large offline networks, data")
# Out:
# Text(0.5, 1.0, 'Similarity vs. complementarity of large offline networks, data')

# %%
sns.boxplot(data=df[["data_comp_g", "data_sim_g"]], orient="h", palette="Paired")
plt.title("Global complementarity and global similarity of large offline networks")
# Out:
# c:\users\masav\appdata\local\programs\python\python310\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# Text(0.5, 1.0, 'Global complementarity and global similarity of large offline networks')

# %%
sns.boxplot(data=df[["data_comp", "data_sim"]], orient="h", palette="Paired")
plt.title("Global complementarity and global similarity of large offline networks")
# Out:
# c:\users\masav\appdata\local\programs\python\python310\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# Text(0.5, 1.0, 'Global complementarity and global similarity of large offline networks')

# %%
sns.boxplot(data=df[["data_comp_e", "data_sim_e"]], orient="h", palette="Paired")
plt.title("Global complementarity and global similarity of large offline networks")
# Out:
# c:\users\masav\appdata\local\programs\python\python310\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# Text(0.5, 1.0, 'Global complementarity and global similarity of large offline networks')

# %%
df[df["data_sim_g"] < 0.1]
# Out:
#     Unnamed: 0  _  idx  dataset              name  n_nodes  frac_total  \
# 4            0  0    1      NaN             crime     1263    0.915217
# 5            0  0    1      NaN             crime     1263    0.915217
# 14           0  0    1      NaN     friendship-11      250    1.000000
# 15           0  0    1      NaN     friendship-12      229    1.000000
# 16           0  0    1      NaN     friendship-16      372    1.000000
# 17           0  0    1      NaN      friendship-4      320    1.000000
# 18           0  0    1      NaN      friendship-8      369    1.000000
# 19           0  0    1      NaN  health-advice_11      234    0.975000
# 20           0  0    1      NaN  health-advice_16      349    0.997143
# 21           0  0    1      NaN   health-advice_4      316    1.000000
# 22           0  0    1      NaN   health-advice_8      361    1.000000
#
#      density       dbar       dcv  ...  degree_assortativity  \
# 4   0.001728   2.180523  1.002800  ...                 -0.17
# 5   0.001728   2.180523  1.002800  ...                 -0.17
# 14  0.034153   8.504000  0.700219  ...                 -0.12
# 15  0.033402   7.615721  0.856621  ...                 -0.06
# 16  0.019882   7.376344  0.716235  ...                 -0.04
# 17  0.040674  12.975000  0.656773  ...                 -0.09
# 18  0.025819   9.501355  0.703625  ...                 -0.04
# 19  0.019332   4.504274  1.666350  ...                 -0.21
# 20  0.014195   4.939828  2.205252  ...                 -0.20
# 21  0.020997   6.613924  0.962691  ...                 -0.10
# 22  0.019037   6.853186  1.044779  ...                 -0.14
#
#     global_clustering  diameter  relative_size_of_largest_component  \
# 4                0.00        32                                0.92
# 5                0.00        32                                0.92
# 14               0.10         5                                1.00
# 15               0.09         6                                1.00
# 16               0.06         7                                1.00
# 17               0.09         5                                1.00
# 18               0.06         5                                1.00
# 19               0.05         8                                0.97
# 20               0.05         7                                1.00
# 21               0.05         6                                1.00
# 22               0.05         7                                1.00
#
#           kind        mode  node_properties  edge_properties  gml_file_size  \
# 4   Undirected   Bipartite             meta              NaN          35840
# 5   Undirected   Bipartite             meta              NaN          35840
# 14  Undirected  Unipartite             name              NaN          15360
# 15  Undirected  Unipartite             name              NaN          13312
# 16  Undirected  Unipartite             name              NaN          20480
# 17  Undirected  Unipartite             name              NaN          21504
# 18  Undirected  Unipartite             name              NaN          22528
# 19  Undirected  Unipartite             name              NaN          12288
# 20  Undirected  Unipartite             name              NaN          18432
# 21  Undirected  Unipartite             name              NaN          17408
# 22  Undirected  Unipartite             name              NaN          20480
#
#     nodes_qcut
# 4        large
# 5        large
# 14       large
# 15       large
# 16       large
# 17       large
# 18       large
# 19       large
# 20       large
# 21       large
# 22       large
#
# [11 rows x 40 columns]

# %%
df[df["data_sim_g"] > 0.35]
# Out:
#     Unnamed: 0  _  idx  dataset       name  n_nodes  frac_total   density  \
# 0            0  0    1      NaN    contact      274    1.000000  0.056790
# 1            0  0    1      NaN    contact      274    1.000000  0.056790
# 6            0  0    1      NaN     InVS15      219    0.943966  0.700641
# 7            0  0    1      NaN     InVS15      219    0.943966  0.700641
# 8            0  0    1      NaN       SFHH      403    1.000000  0.908077
# 9            0  0    1      NaN       SFHH      403    1.000000  0.908077
# 10           0  0    1      NaN   facebook      156    0.474164  0.118859
# 11           0  0    1      NaN   facebook      156    0.474164  0.118859
# 12           0  0    1      NaN  proximity      327    0.993921  0.109154
# 13           0  0    1      NaN  proximity      327    0.993921  0.109154
#
#           dbar       dcv  ...  degree_assortativity  global_clustering  \
# 0    15.503650  1.629853  ...                 -0.05               0.90
# 1    15.503650  1.629853  ...                 -0.05               0.90
# 6   152.739726  0.242809  ...                  0.26               0.88
# 7   152.739726  0.242809  ...                  0.26               0.88
# 8   365.047146  0.137335  ...                  0.11               0.97
# 9   365.047146  0.137335  ...                  0.11               0.97
# 10   18.423077  0.523348  ...                  0.02               0.52
# 11   18.423077  0.523348  ...                  0.02               0.52
# 12   35.584098  0.379312  ...                  0.47               0.61
# 13   35.584098  0.379312  ...                  0.47               0.61
#
#     diameter  relative_size_of_largest_component        kind        mode  \
# 0          4                                1.00  Undirected  Unipartite
# 1          4                                1.00  Undirected  Unipartite
# 6          3                                0.94  Undirected  Unipartite
# 7          3                                0.94  Undirected  Unipartite
# 8          2                                1.00  Undirected  Unipartite
# 9          2                                1.00  Undirected  Unipartite
# 10         5                                0.47  Undirected  Unipartite
# 11         5                                0.47  Undirected  Unipartite
# 12         4                                0.99  Undirected  Unipartite
# 13         4                                0.99  Undirected  Unipartite
#
#       node_properties  edge_properties  gml_file_size  nodes_qcut
# 0                 NaN     weight  time         153600       large
# 1                 NaN     weight  time         153600       large
# 6           id  group             time        3879731       large
# 7           id  group             time        3879731       large
# 8           id  group             time        4194304       large
# 9           id  group             time        4194304       large
# 10  id  class  gender              NaN          13312       large
# 11  id  class  gender              NaN          13312       large
# 12  id  class  gender             time         588800       large
# 13  id  class  gender             time         588800       large
#
# [10 rows x 40 columns]

# %%
df[df["data_sim_g"] < df["data_comp_g"]] # only in the bipartite networks the complementarity was higher
# Out:
#    Unnamed: 0  _  idx  dataset   name  n_nodes  frac_total   density  \
# 4           0  0    1      NaN  crime     1263    0.915217  0.001728
# 5           0  0    1      NaN  crime     1263    0.915217  0.001728
#
#        dbar     dcv  ...  degree_assortativity  global_clustering  diameter  \
# 4  2.180523  1.0028  ...                 -0.17                0.0        32
# 5  2.180523  1.0028  ...                 -0.17                0.0        32
#
#    relative_size_of_largest_component        kind       mode  node_properties  \
# 4                                0.92  Undirected  Bipartite             meta
# 5                                0.92  Undirected  Bipartite             meta
#
#    edge_properties  gml_file_size  nodes_qcut
# 4              NaN          35840       large
# 5              NaN          35840       large
#
# [2 rows x 40 columns]

# %%
df["data_sim_g"].hist(density=True, bins=10)
plt.title("Global similarity of large offline networks")
plt.xlabel("Global similarity coefficient")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')

# %%
df["data_comp_g"].hist(density=True, bins=10)
plt.title("Global complementarity of large offline networks")
plt.xlabel("Global complementarity coefficient")
plt.ylabel("Density")
# Out:
# Text(0, 0.5, 'Density')
