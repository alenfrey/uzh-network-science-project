# %% [markdown]
# ### Analyse structural coefficients of large networks

# %%
from lib import *
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(DATA_DIR_PATH / "structural_measures_large_online.csv")

# %%
df.columns
# Out:
# Index(['_', 'idx', 'dataset', 'name', 'n_nodes', 'frac_total', 'density',
#        'dbar', 'dcv', 'dmax', 'null_10_sim_g', 'null_10_sim', 'null_10_sim_e',
#        'null_10_comp_g', 'null_10_comp', 'null_10_comp_e', 'data_sim_g',
#        'data_sim', 'data_sim_e', 'data_comp_g', 'data_comp', 'data_comp_e'],
#       dtype='object')

# %%
df[_]
# Out:
#    _  idx  dataset                         name  n_nodes  frac_total  \
# 0  0    1      NaN          NYC_restaurant_tips     5372    0.838066
# 1  0    1      NaN       NYC_restaurant_checkin     4906    0.993922
# 2  0    1      NaN  gplus_112573107772208475213     3794    0.998684
# 3  0    1      NaN  gplus_115455024457484679647     3464    0.992550
# 4  0    1      NaN            facebook_combined     4039    1.000000
# 5  0    1      NaN                           M2     3862    1.000000
# 6  0    1      NaN                           L2     5524    1.000000
# 7  0    1      NaN                           L1     5793    1.000000
#
#     density       dbar       dcv  dmax  ...  null_10_sim_e  null_10_comp_g  \
# 0  0.000614   3.295607  1.569503   196  ...       0.003296        0.004668
# 1  0.001118   5.485936  1.044863    88  ...       0.003480        0.004561
# 2  0.008368  31.738535  1.780662   548  ...       0.085803        0.051862
# ...
