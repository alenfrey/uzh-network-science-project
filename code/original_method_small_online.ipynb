# %% [markdown]
# ## We run the methods of the paper on additional social networks
# ### In this notebook, we run it on smallonline social networks

# %%
# reload imported files automatically without restarting the kernel
# %load_ext autoreload
# %autoreload 2

# %%
from lib import *
from pathcensus import PathCensus
from pathcensus.nullmodels import UBCM
from pathcensus.inference import Inference
from pathcensus.utils import set_seed
from mandarina.benchmark import timer
import networkx as nx

# %%
@timer
def calculate_structural_measures(network_name, g, n_samples_null_model):
    """
    This function calculates the structural measures of a network and 
    its null model average values by fitting a UBCM null model to the network.
    """
    n_total = g.number_of_nodes()  # get total number of nodes
    # remove self-loops and multiedges and get largest connected component
    g = preprocess_graph(g)  ; g
    n_giant = g.number_of_nodes()  # get number of nodes in largest connected component
    degseq = sorted([d for n, d in g.degree()], reverse=True)  # get degree sequence
    dataset = ""
    network_name = network_name.split(".")[0]
    label = "small online"
    
    properties = {
            "idx": 1,
            "dataset": dataset,
            "name": network_name,
            #"graph": [g],  # get graph
            "n_nodes": n_giant,  # get number of nodes in largest connected component
            "frac_total": n_giant
            / n_total,  # get fraction of nodes in largest connected component
            "density": nx.density(g),  # get density
            "dbar": np.mean(degseq),  # get mean degree
            "dcv": np.std(degseq)
            / np.mean(degseq),  # get coefficient of variation of degree
            "dmax": np.max(degseq),  # get maximum degree
        }
    
    model = UBCM(g)  # initialize model
    model.fit()  # fit model
    model.validate()  # validate model
    # compare null model to actual graph using statistics function
    infer = Inference(g, model, statistics)
    data, null = infer.init_comparison(n=n_samples_null_model)
    original_network_values = dict(data)
    original_network_values = {'data_' + k: v for k, v in original_network_values.items()}
    null_model_mean_values = dict(null.mean(numeric_only=True)) 
    null_model_mean_values = {f'null_{n_samples_null_model}_{k}': v for k, v in null_model_mean_values.items()}
    return properties | null_model_mean_values |original_network_values | null_model_mean_values

# %%
OUTPUT_CSV_FILE_PATH = DATA_DIR_PATH / "structural_measures_small_online.csv"

# %%
file_filter = lambda file: file.is_file()
small_online_network_files = list(filter(file_filter, (DATA_DIR_PATH / "online" / "small").glob("**/*")))

results = []
for i, file in enumerate(small_online_network_files): # loop over all online small social network files
    file_size = file.stat().st_size
    print(file_size)
    if file_size > 200000000: 
        continue
    f = gml_cleaner(file) # clean gml file
    g = nx.read_gml(f, label="id") # load into networkx
    print("Running calculations for network: ", file.name) 
    # calculate measures from original network and null model
    result = calculate_structural_measures(file.name.split(".")[0] , g, n_samples_null_model=100) 
    df = pd.DataFrame(result).reset_index()
    df[df.columns[:-1]].to_csv(OUTPUT_CSV_FILE_PATH, mode='a', header=not OUTPUT_CSV_FILE_PATH.is_file()) # append result row to csv file
    results.append(result) # collect results
# Out:
# 57449
# Running calculations for network:  S2.gml
# Function calculate_structural_measures with args (('S2', <networkx.classes.multigraph.MultiGraph object at 0x176796a10>), {'n_samples_null_model': 100}) took: 10.1784 seconds.
# 171298
# Running calculations for network:  S1.gml
# Function calculate_structural_measures with args (('S1', <networkx.classes.multigraph.MultiGraph object at 0x1778c1300>), {'n_samples_null_model': 100}) took: 3.0230 seconds.
# 263906
# Running calculations for network:  facebook_friends.gml
# Function calculate_structural_measures with args (('facebook_friends', <networkx.classes.multigraph.MultiGraph object at 0x10d758c40>), {'n_samples_null_model': 100}) took: 2.4783 seconds.
# 280129
# Running calculations for network:  gplus_114054672576929802335.gml
# Function calculate_structural_measures with args (('gplus_114054672576929802335', <networkx.classes.multigraph.MultiGraph object at 0x178679600>), {'n_samples_null_model': 100}) took: 5.5956 seconds.
# 10016
# Running calculations for network:  gplus_116899029375914044550.gml
# Function calculate_structural_measures with args (('gplus_116899029375914044550', <networkx.classes.multigraph.MultiGraph object at 0x1781b3d00>), {'n_samples_null_model': 100}) took: 0.9351 seconds.
# 23808
# Running calculations for network:  facebook_3980.gml
# Function calculate_structural_measures with args (('facebook_3980', <networkx.classes.multigraph.MultiGraph object at 0x10d6e58d0>), {'n_samples_null_model': 100}) took: 1.1185 seconds.
# 419120
# Running calculations for network:  gplus_103251633033550231172.gml
# Function calculate_structural_measures with args (('gplus_103251633033550231172', <networkx.classes.multigraph.MultiGraph object at 0x1786663e0>), {'n_samples_null_model': 100}) took: 10.9173 seconds.
# 339577
# Running calculations for network:  facebook_348.gml
# Function calculate_structural_measures with args (('facebook_348', <networkx.classes.multigraph.MultiGraph object at 0x1786da980>), {'n_samples_null_model': 100}) took: 5.3761 seconds.
# 96976
# Running calculations for network:  gplus_117412175333096244275.gml
# Function calculate_structural_measures with args (('gplus_117412175333096244275', <networkx.classes.multigraph.MultiGraph object at 0x1786ea050>), {'n_samples_null_model': 100}) took: 1.4734 seconds.
# 52973
# Running calculations for network:  gplus_110241952466097562819.gml
# Function calculate_structural_measures with args (('gplus_110241952466097562819', <networkx.classes.multigraph.MultiGraph object at 0x1786afac0>), {'n_samples_null_model': 100}) took: 1.3483 seconds.
# 515333
# Running calculations for network:  gplus_113597493946570654755.gml
# Function calculate_structural_measures with args (('gplus_113597493946570654755', <networkx.classes.multigraph.MultiGraph object at 0x1780b0730>), {'n_samples_null_model': 100}) took: 17.1945 seconds.
# 1032346
# Running calculations for network:  gplus_101541879642294398860.gml
# Function calculate_structural_measures with args (('gplus_101541879642294398860', <networkx.classes.multigraph.MultiGraph object at 0x177f40bb0>), {'n_samples_null_model': 100}) took: 44.4190 seconds.
# 1001931
# Running calculations for network:  gplus_100500197140377336562.gml
# Function calculate_structural_measures with args (('gplus_100500197140377336562', <networkx.classes.multigraph.MultiGraph object at 0x1779e2f50>), {'n_samples_null_model': 100}) took: 38.3106 seconds.
# 845230
# Running calculations for network:  gplus_107459220492917008623.gml
# Function calculate_structural_measures with args (('gplus_107459220492917008623', <networkx.classes.multigraph.MultiGraph object at 0x17759d240>), {'n_samples_null_model': 100}) took: 30.0687 seconds.
# 1138466
# Running calculations for network:  gplus_107965826228461029730.gml
# Function calculate_structural_measures with args (('gplus_107965826228461029730', <networkx.classes.multigraph.MultiGraph object at 0x1783fd870>), {'n_samples_null_model': 100}) took: 57.5817 seconds.
# 172898
# Running calculations for network:  facebook_414.gml
# Function calculate_structural_measures with args (('facebook_414', <networkx.classes.multigraph.MultiGraph object at 0x1773edb70>), {'n_samples_null_model': 100}) took: 2.7134 seconds.
# 87824
# Running calculations for network:  gplus_102615863344410467759.gml
# Function calculate_structural_measures with args (('gplus_102615863344410467759', <networkx.classes.multigraph.MultiGraph object at 0x1773ed3f0>), {'n_samples_null_model': 100}) took: 1.8425 seconds.
# 815091
# Running calculations for network:  gplus_115576988435396060952.gml
# Function calculate_structural_measures with args (('gplus_115576988435396060952', <networkx.classes.multigraph.MultiGraph object at 0x178664fd0>), {'n_samples_null_model': 100}) took: 30.1817 seconds.
# 1089496
# Running calculations for network:  gplus_109342148209917802565.gml
# Function calculate_structural_measures with args (('gplus_109342148209917802565', <networkx.classes.multigraph.MultiGraph object at 0x1786673a0>), {'n_samples_null_model': 100}) took: 52.7467 seconds.
# 851653
# Running calculations for network:  gplus_104105354262797387583.gml
# Function calculate_structural_measures with args (('gplus_104105354262797387583', <networkx.classes.multigraph.MultiGraph object at 0x177424310>), {'n_samples_null_model': 100}) took: 23.1468 seconds.
# 34825
# Running calculations for network:  facebook_698.gml
# Function calculate_structural_measures with args (('facebook_698', <networkx.classes.multigraph.MultiGraph object at 0x177f43790>), {'n_samples_null_model': 100}) took: 1.0535 seconds.
# 416406
# Running calculations for network:  gplus_118255645714452180374.gml
# Function calculate_structural_measures with args (('gplus_118255645714452180374', <networkx.classes.multigraph.MultiGraph object at 0x1779c1d80>), {'n_samples_null_model': 100}) took: 11.8865 seconds.
# 372010
# Running calculations for network:  gplus_101499880233887429402.gml
# Function calculate_structural_measures with args (('gplus_101499880233887429402', <networkx.classes.multigraph.MultiGraph object at 0x1779c22c0>), {'n_samples_null_model': 100}) took: 7.7063 seconds.
# 104349
# Running calculations for network:  gplus_103241736833663734962.gml
# Function calculate_structural_measures with args (('gplus_103241736833663734962', <networkx.classes.multigraph.MultiGraph object at 0x177299420>), {'n_samples_null_model': 100}) took: 2.1239 seconds.
# 263299
# Running calculations for network:  gplus_100466178325794757407.gml
# Function calculate_structural_measures with args (('gplus_100466178325794757407', <networkx.classes.multigraph.MultiGraph object at 0x1777e6050>), {'n_samples_null_model': 100}) took: 4.9044 seconds.
# 512053
# Running calculations for network:  gplus_111213696402662884531.gml
# Function calculate_structural_measures with args (('gplus_111213696402662884531', <networkx.classes.multigraph.MultiGraph object at 0x177f42710>), {'n_samples_null_model': 100}) took: 16.6524 seconds.
# 354355
# Running calculations for network:  gplus_114336431216099933033.gml
# Function calculate_structural_measures with args (('gplus_114336431216099933033', <networkx.classes.multigraph.MultiGraph object at 0x1783f6d70>), {'n_samples_null_model': 100}) took: 6.3776 seconds.
# 1118575
# Running calculations for network:  gplus_100521671383026672718.gml
# Function calculate_structural_measures with args (('gplus_100521671383026672718', <networkx.classes.multigraph.MultiGraph object at 0x177f40370>), {'n_samples_null_model': 100}) took: 41.2223 seconds.
# 717439
# Running calculations for network:  gplus_110614416163543421878.gml
# Function calculate_structural_measures with args (('gplus_110614416163543421878', <networkx.classes.multigraph.MultiGraph object at 0x178191090>), {'n_samples_null_model': 100}) took: 32.3569 seconds.
# 155746
# Running calculations for network:  facebook_686.gml
# Function calculate_structural_measures with args (('facebook_686', <networkx.classes.multigraph.MultiGraph object at 0x1776e30d0>), {'n_samples_null_model': 100}) took: 2.5365 seconds.
# 814844
# Running calculations for network:  gplus_101997124338642780860.gml
# Function calculate_structural_measures with args (('gplus_101997124338642780860', <networkx.classes.multigraph.MultiGraph object at 0x177dd9f30>), {'n_samples_null_model': 100}) took: 27.6673 seconds.
# 2198
# Running calculations for network:  gplus_104076158580173410325.gml
# Function calculate_structural_measures with args (('gplus_104076158580173410325', <networkx.classes.multigraph.MultiGraph object at 0x177f857e0>), {'n_samples_null_model': 100}) took: 0.8563 seconds.
# 586754
# Running calculations for network:  gplus_114104634069486127920.gml
# Function calculate_structural_measures with args (('gplus_114104634069486127920', <networkx.classes.multigraph.MultiGraph object at 0x177f872b0>), {'n_samples_null_model': 100}) took: 22.9128 seconds.
# 427745
# Running calculations for network:  gplus_103503116383846951534.gml
# Function calculate_structural_measures with args (('gplus_103503116383846951534', <networkx.classes.multigraph.MultiGraph object at 0x177a09c90>), {'n_samples_null_model': 100}) took: 10.0112 seconds.
# 243113
# Running calculations for network:  gplus_100637660947564674695.gml
# Function calculate_structural_measures with args (('gplus_100637660947564674695', <networkx.classes.multigraph.MultiGraph object at 0x178022b00>), {'n_samples_null_model': 100}) took: 4.6479 seconds.
# 751066
# Running calculations for network:  gplus_117503822947457399073.gml
# Function calculate_structural_measures with args (('gplus_117503822947457399073', <networkx.classes.multigraph.MultiGraph object at 0x1776f4610>), {'n_samples_null_model': 100}) took: 30.9392 seconds.
# 1774412
# Running calculations for network:  gplus_100962871525684315897.gml
# Function calculate_structural_measures with args (('gplus_100962871525684315897', <networkx.classes.multigraph.MultiGraph object at 0x1774aad70>), {'n_samples_null_model': 100}) took: 112.0978 seconds.
# 1231209
# Running calculations for network:  gplus_104672614700283598130.gml
# Function calculate_structural_measures with args (('gplus_104672614700283598130', <networkx.classes.multigraph.MultiGraph object at 0x177bb40a0>), {'n_samples_null_model': 100}) took: 75.5164 seconds.
# 21438
# Running calculations for network:  gplus_110739220927723360152.gml
# Function calculate_structural_measures with args (('gplus_110739220927723360152', <networkx.classes.multigraph.MultiGraph object at 0x178128d90>), {'n_samples_null_model': 100}) took: 1.0792 seconds.
# 12099
# Running calculations for network:  gplus_103338524411980406972.gml
# Function calculate_structural_measures with args (('gplus_103338524411980406972', <networkx.classes.multigraph.MultiGraph object at 0x1780746a0>), {'n_samples_null_model': 100}) took: 0.9649 seconds.
# 160265
# Running calculations for network:  gplus_113455290791279442483.gml
# Function calculate_structural_measures with args (('gplus_113455290791279442483', <networkx.classes.multigraph.MultiGraph object at 0x17812ae60>), {'n_samples_null_model': 100}) took: 3.3414 seconds.
# 18861
# Running calculations for network:  gplus_106328207304735502636.gml
# Function calculate_structural_measures with args (('gplus_106328207304735502636', <networkx.classes.multigraph.MultiGraph object at 0x17757ddb0>), {'n_samples_null_model': 100}) took: 1.0272 seconds.
# 8764
# Running calculations for network:  gplus_101560853443212199687.gml
# Function calculate_structural_measures with args (('gplus_101560853443212199687', <networkx.classes.multigraph.MultiGraph object at 0x177f648e0>), {'n_samples_null_model': 100}) took: 0.9525 seconds.
# 218986
# Running calculations for network:  gplus_110581012109008817546.gml
# Function calculate_structural_measures with args (('gplus_110581012109008817546', <networkx.classes.multigraph.MultiGraph object at 0x178160310>), {'n_samples_null_model': 100}) took: 3.0050 seconds.
# 820868
# Running calculations for network:  gplus_112317819390625199896.gml
# Function calculate_structural_measures with args (('gplus_112317819390625199896', <networkx.classes.multigraph.MultiGraph object at 0x1774256c0>), {'n_samples_null_model': 100}) took: 33.7540 seconds.
# 81893
# Running calculations for network:  gplus_117798157258572080176.gml
# Function calculate_structural_measures with args (('gplus_117798157258572080176', <networkx.classes.multigraph.MultiGraph object at 0x177425c00>), {'n_samples_null_model': 100}) took: 1.6463 seconds.
# 64961
# Running calculations for network:  gplus_116450966137824114154.gml
# Function calculate_structural_measures with args (('gplus_116450966137824114154', <networkx.classes.multigraph.MultiGraph object at 0x1777e51b0>), {'n_samples_null_model': 100}) took: 1.5323 seconds.
# 44991
# Running calculations for network:  gplus_110809308822849680310.gml
# Function calculate_structural_measures with args (('gplus_110809308822849680310', <networkx.classes.multigraph.MultiGraph object at 0x1783f4bb0>), {'n_samples_null_model': 100}) took: 1.2338 seconds.
# 409492
# Running calculations for network:  gplus_108404515213153345305.gml
# Function calculate_structural_measures with args (('gplus_108404515213153345305', <networkx.classes.multigraph.MultiGraph object at 0x177dc11e0>), {'n_samples_null_model': 100}) took: 9.5510 seconds.
# 61855
# Running calculations for network:  gplus_117866881767579360121.gml
# Function calculate_structural_measures with args (('gplus_117866881767579360121', <networkx.classes.multigraph.MultiGraph object at 0x177362dd0>), {'n_samples_null_model': 100}) took: 1.4482 seconds.
# 1782580
# Running calculations for network:  gplus_112737356589974073749.gml
# Function calculate_structural_measures with args (('gplus_112737356589974073749', <networkx.classes.multigraph.MultiGraph object at 0x177fcfa00>), {'n_samples_null_model': 100}) took: 139.1694 seconds.
# 429149
# Running calculations for network:  facebook_0.gml
# Function calculate_structural_measures with args (('facebook_0', <networkx.classes.multigraph.MultiGraph object at 0x177e8a440>), {'n_samples_null_model': 100}) took: 3.4529 seconds.
# 75930
# Running calculations for network:  gplus_101848191156408080085.gml
# Function calculate_structural_measures with args (('gplus_101848191156408080085', <networkx.classes.multigraph.MultiGraph object at 0x177b584c0>), {'n_samples_null_model': 100}) took: 1.8492 seconds.
# 83434
# Running calculations for network:  gplus_110232479818136355682.gml
# Function calculate_structural_measures with args (('gplus_110232479818136355682', <networkx.classes.multigraph.MultiGraph object at 0x177a947c0>), {'n_samples_null_model': 100}) took: 2.0716 seconds.
# 2290268
# Running calculations for network:  gplus_115360471097759949621.gml
# Function calculate_structural_measures with args (('gplus_115360471097759949621', <networkx.classes.multigraph.MultiGraph object at 0x177b585b0>), {'n_samples_null_model': 100}) took: 112.7668 seconds.
# 793347
# Running calculations for network:  facebook_3437.gml
# Function calculate_structural_measures with args (('facebook_3437', <networkx.classes.multigraph.MultiGraph object at 0x1773a7d00>), {'n_samples_null_model': 100}) took: 5.9821 seconds.
# 562024
# Running calculations for network:  gplus_100518419853963396365.gml
# Function calculate_structural_measures with args (('gplus_100518419853963396365', <networkx.classes.multigraph.MultiGraph object at 0x178022ce0>), {'n_samples_null_model': 100}) took: 20.5263 seconds.

# %%
df = pd.concat([pd.DataFrame(result) for result in results]).reset_index() # combine all data to dataframe for analysis
df = df[df.columns[:-1]]

# %%
df
# Out:
#     _  idx dataset                         name  n_nodes  frac_total  \
# 0   0    1                                   S2      165    1.000000
# 1   0    1                                   S1      320    1.000000
# 2   0    1                     facebook_friends      329    0.908840
# 3   0    1          gplus_114054672576929802335      175    1.000000
# 4   0    1          gplus_116899029375914044550       22    1.000000
# 5   0    1                        facebook_3980       44    0.846154
# 6   0    1          gplus_103251633033550231172      371    0.994638
# 7   0    1                         facebook_348      224    1.000000
# 8   0    1          gplus_117412175333096244275      222    0.880952
# 9   0    1          gplus_110241952466097562819       83    1.000000
# 10  0    1          gplus_113597493946570654755      321    1.000000
# 11  0    1          gplus_101541879642294398860      486    0.995902
# 12  0    1          gplus_100500197140377336562      638    1.000000
# 13  0    1          gplus_107459220492917008623      562    1.000000
# 14  0    1          gplus_107965826228461029730      495    1.000000
# 15  0    1                         facebook_414      148    0.986667
# 16  0    1          gplus_102615863344410467759      102    1.000000
# 17  0    1          gplus_115576988435396060952      492    1.000000
# 18  0    1          gplus_109342148209917802565      550    1.000000
# 19  0    1          gplus_104105354262797387583      452    1.000000
# 20  0    1                         facebook_698       40    0.655738
# 21  0    1          gplus_118255645714452180374      215    1.000000
# 22  0    1          gplus_101499880233887429402      268    1.000000
# 23  0    1          gplus_103241736833663734962      131    1.000000
# 24  0    1          gplus_100466178325794757407      342    0.994186
# 25  0    1          gplus_111213696402662884531      258    1.000000
# 26  0    1          gplus_114336431216099933033      455    0.986985
# 27  0    1          gplus_100521671383026672718      521    1.000000
# 28  0    1          gplus_110614416163543421878      338    1.000000
# 29  0    1                         facebook_686      168    1.000000
# 30  0    1          gplus_101997124338642780860      575    1.000000
# 31  0    1          gplus_104076158580173410325        8    1.000000
# 32  0    1          gplus_114104634069486127920      320    1.000000
# 33  0    1          gplus_103503116383846951534      422    1.000000
# 34  0    1          gplus_100637660947564674695      296    1.000000
# 35  0    1          gplus_117503822947457399073      301    0.980456
# 36  0    1          gplus_100962871525684315897      559    1.000000
# 37  0    1          gplus_104672614700283598130      475    1.000000
# 38  0    1          gplus_110739220927723360152       54    1.000000
# 39  0    1          gplus_103338524411980406972       34    1.000000
# 40  0    1          gplus_113455290791279442483      108    1.000000
# 41  0    1          gplus_106328207304735502636       35    1.000000
# 42  0    1          gplus_101560853443212199687       19    1.000000
# 43  0    1          gplus_110581012109008817546      627    1.000000
# 44  0    1          gplus_112317819390625199896      498    1.000000
# 45  0    1          gplus_117798157258572080176      168    1.000000
# 46  0    1          gplus_116450966137824114154       92    1.000000
# 47  0    1          gplus_110809308822849680310       97    1.000000
# 48  0    1          gplus_108404515213153345305      417    1.000000
# 49  0    1          gplus_117866881767579360121      117    1.000000
# 50  0    1          gplus_112737356589974073749      474    0.995798
# 51  0    1                           facebook_0      324    0.972973
# 52  0    1          gplus_101848191156408080085       94    1.000000
# 53  0    1          gplus_110232479818136355682      116    0.966667
# 54  0    1          gplus_115360471097759949621      511    1.000000
# 55  0    1                        facebook_3437      532    0.996255
# 56  0    1          gplus_100518419853963396365      326    1.000000
#
#      density        dbar       dcv  dmax  ...  null_100_sim_e  \
# 0   0.053659    8.800000  0.946063    63  ...        0.138034
