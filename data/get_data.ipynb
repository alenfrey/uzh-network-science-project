# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
df = pd.read_html("https://networks.skewed.de/")[0] # get a df of all networks on Netzschleuder

# %%
df.columns
# Out:
# Index(['Name', 'Title', 'Nodes', 'Edges', '$\left<k\right>$', '$\sigma_k$',
#        '$\lambda_h$', '$\tau$', '$r$', '$c$', '$\oslash$', '$S$', 'Kind',
#        'Mode', '$n$', 'Tags'],
#       dtype='object')

# %%
social_networks = df["Tags"].str.contains("Social")
unweighted = df["Tags"].str.contains("Unweighted")
online = df["Tags"].str.contains("Online")
offline = df["Tags"].str.contains("Offline")
undirected = df["Kind"] == "Undirected"

# %%
alt.Chart(df[social_networks & unweighted & online & undirected]).mark_bar().encode(
    alt.X("Nodes:Q", bin=True),
    y='count()',
)
# Out:
# /home/af/miniconda3/envs/ns-project/lib/python3.8/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
sns.histplot(data=df[social_networks & unweighted & online & undirected], x="Nodes")
# Out:
# <AxesSubplot: xlabel='Nodes', ylabel='Count'>

# %%
plt.hist(["Nodes"])
# Out:
# (array([34.,  0.,  0.,  0.,  0.,  0.,  1.,  0.,  1.,  1.]),
#  array([3.62000000e+02, 6.56116240e+06, 1.31219628e+07, 1.96827632e+07,
#         2.62435636e+07, 3.28043640e+07, 3.93651644e+07, 4.59259648e+07,
#         5.24867652e+07, 5.90475656e+07, 6.56083660e+07]),
#  <BarContainer object of 10 artists>)

# %%
df[social_networks & unweighted & online & undirected] # get unweighted online social networks
# Out:
#                        Name                                            Title  \
# 1              academia_edu                             Academica.edu (2011)
# 8                   anybeat                    Anybeat social network (2013)
# 66               digg_reply                        Digg reply network (2008)
# 74                   douban                 Douban friendship network (2009)
# 82               ego_social              Ego networks in social media (2012)
# 89           epinions_trust                    Epinions trust network (2003)
# 96         facebook_friends                    Maier Facebook friends (2014)
# 97   facebook_organizations  Within-organization Facebook friendships (2013)
# 103           flickr_aminer                              Flickr social graph
# 104           flickr_groups                           OSN user groups (2007)
# 105           flickr_growth                 Flickr friendship network (2008)
# 106                flixster               Flixster friendship network (2009)
# 114              foursquare                Foursquare NYC restaurants (2012)
# 115  foursquare_friendships             Foursquare global friendships (2013)
# 116       foursquare_global               Foursquare global check-ins (2013)
# 125             google_plus                                   Google+ (2013)
# 132                   hyves                  Hyves friendship network (2010)
# 133                 inploid           Inploid: an online social Q&A platform
# 149                  lastfm                  last.fm listening habits (2007)
# 150           lastfm_aminer                             Last.fm social graph
# 155             livejournal                LiveJournal social network (2006)
# 156      livejournal_aminer                         Livejournal social graph
# 157               livemocha              Livemocha friendship network (2010)
# 166             marker_cafe                           The Marker Cafe (2011)
# 171             mislove_osn                  Mislove et al. OSNs (2006-2007)
# 178          myspace_aminer                             MySpace social graph
# 189                 petster                 Pet owner social networks (2016)
# 190              pgp_strong                          PGP web of trust (2009)
# 201                 prosper                        Prosper user loans (2016)
# 203                 qa_user         User interactions on Q&A websites (2016)
# 216           soc_net_comms                     Networks with group metadata
# 240                 twitter                         Twitter followers (2010)
# 241             twitter_15m                     Twitter 15-M movement (2011)
# 242            twitter_2009                             Twitter graph (2009)
# 243          twitter_events                    Twitter, 5 events (2013-2014)
# 245          twitter_sample                            Twitter sample (2014)
# 246          twitter_social                             Twitter social graph
#
#         Nodes       Edges  $\left<k\right>$  $\sigma_k$  $\lambda_h$  \
# 1      200169     1398063              6.98       46.24       109.99
# 8       12645       67053              5.30       89.97        92.23
# 66      30398       87627              2.88       11.73        28.31
# 74     154908      327162              4.22       11.75        39.78
# 82     107614    12238285            227.45      581.50      1718.72
# 89      75888      508837              6.71       52.66       181.65
# 96        362        1988             10.98       10.83        23.30
# 97       5793       45266             15.63       30.36        56.27
# 103    214626     9114557             42.47      199.29       706.39
# 104    499610     8545307             34.21      194.73       579.50
# 105   2302925    33140017             14.39      198.55      1326.76
# 106   2523386     7918801              6.28       36.64       145.66
# 114      6410       10377              3.24        5.67         9.47
# 115    114324      363704              6.36       13.59        79.68
# 116   3935215    22809624             11.59       62.44       163.10
# 125    211187     1506896              7.14       47.02       261.48
# 132   1402673     2777419              3.96       45.30       113.02
# 133     39749       57276              1.44       42.25        81.50
# 149   1085612    19150868             35.28      915.72       589.26
# 150    136409     1685524             12.36       62.52       296.00
# 155   4847571    68993773             14.23       72.29       514.56
# 156   3017286    87037567             28.85      779.36       967.85
# 157    104103     2193083             42.13      109.68       272.53
# 166     69413     1644849             47.39      176.63       465.81
# 171   5204176    77402652             14.87       71.17       539.58
# 178    854498     6489736              7.59       61.61       188.16
# 189    623766    15699276             50.34      469.04      1189.48
# 190     39796      301498              7.58       36.51       101.60
# 201     89269     3394979             38.03      145.96       327.23
# 203   2601977    63497050             24.40      436.50       713.99
# 216  65608366  1806067135             55.06      137.81       830.62
# 240    465017      834797              1.80       28.35        77.74
# 241     87569     6030459             68.87      471.29       666.53
# 242  52579682  1963263821             37.34     2698.38      7004.31
# 243   2281259     4061960              1.78       48.90       166.63
# 245   5384162    16011444              2.97       47.65       431.87
# 246  41652230  1468365182             35.25     2534.99      6281.30
#
#        $\tau$   $r$   $c$  $\oslash$   $S$        Kind        Mode  $n$  \
# 1       78.34 -0.02  0.04         16  1.00  Undirected  Unipartite    1
# 8       41.02 -0.12  0.02         10  1.00  Undirected  Unipartite    1
# 66      26.22  0.04  0.01         12  0.98  Undirected  Unipartite    1
# 74     103.63 -0.18  0.01          9  1.00  Undirected  Unipartite    1
# 82     110.57 -0.08  0.15          6  1.00  Undirected  Unipartite  143
# 89     208.29 -0.01  0.08         15  1.00  Undirected  Unipartite    1
# 96      78.68  0.10  0.51          9  0.91  Undirected  Unipartite    1
# 97    2931.02  0.18  0.31         16  1.00  Undirected  Unipartite    6
# 103     33.23 -0.02  0.08         10  1.00  Undirected  Unipartite    1
# 104    207.93 -0.09  0.00         18  0.94  Undirected   Bipartite    1
# 105   1330.21  0.03  0.13         23  0.94  Undirected  Unipartite    1
# 106    108.52 -0.32  0.01          8  1.00  Undirected  Unipartite    1
# 114     92.11 -0.04  0.00         19  0.84  Undirected   Bipartite    2
# 115    753.87  0.13  0.12         28  0.92  Undirected  Unipartite    2
