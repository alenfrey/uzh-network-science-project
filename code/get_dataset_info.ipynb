# %%
import urllib.request, json

# %%
def get_all_netzschleuder_network_keys():
    with urllib.request.urlopen("https://networks.skewed.de/api/nets") as url:
        data = json.load(url)
        return list(data)


def get_netzschleuder_network_info(network_key):
    """
    Returns a dictionary with infos for a given network key
    """
    with urllib.request.urlopen("https://networks.skewed.de/api/net/" + network_key) as url:
        data = json.load(url)
        return data

# %%
get_all_netzschleuder_network_keys()
# Out:
# ['7th_graders',
#  'academia_edu',
#  'add_health',
#  'adjnoun',
#  'advogato',
#  'amazon_copurchases',
#  'amazon_ratings',
#  'ambassador',
#  'anybeat',
#  'arxiv_authors',
#  'arxiv_citation',
#  'arxiv_collab',
#  'as_skitter',
#  'bag_of_words',
#  'baidu',
#  'baseball',
#  'berkstan_web',
#  'bible_nouns',
#  'bibsonomy',
#  'bison',
#  'bitcoin',
#  'bitcoin_alpha',
#  'bitcoin_trust',
#  'blumenau_drug',
#  'board_directors',
#  'bookcrossing',
#  'budapest_connectome',
#  'caida_as',
#  'cattle',
#  'celegans_2019',
#  'celegans_interactomes',
#  'celegans_metabolic',
#  'celegansneural',
#  'ceo_club',
#  'chess',
#  'chicago_road',
#  'cintestinalis',
#  'citeseer',
#  'citeulike',
#  'college_freshmen',
#  'collins_yeast',
#  'contact',
#  'contiguous_usa',
#  'copenhagen',
#  'cora',
#  'corporate_directors',
#  'crime',
#  'cs_department',
#  'dblp_author_paper',
#  'dblp_cite',
#  'dblp_coauthor',
#  'dblp_coauthor_snap',
#  'dblp_simplices',
#  'dbpedia_all',
#  'dbpedia_country',
#  'dbpedia_genre',
#  'dbpedia_link',
#  'dbpedia_location',
#  'dbpedia_occupation',
#  'dbpedia_producer',
#  'dbpedia_recordlabel',
#  'dbpedia_starring',
#  'dbpedia_team',
#  'dbpedia_writer',
#  'dbtropes_feature',
#  'delicious',
#  'digg_reply',
#  'digg_votes',
#  'discogs_affiliation',
#  'discogs_genre',
#  'discogs_label',
#  'dnc',
#  'dolphins',
#  'dom',
#  'douban',
#  'dutch_criticism',
#  'dutch_school',
#  'ecoli_transcription',
#  'edit_wikibooks',
#  'edit_wikinews',
#  'edit_wikiquote',
#  'edit_wiktionary',
#  'ego_social',
#  'elec',
#  'elite',
#  'email_company',
#  'email_enron',
#  'email_eu',
#  'epinions',
#  'epinions_trust',
#  'escorts',
#  'eu_airlines',
#  'eu_procurements',
#  'eu_procurements_alt',
#  'euroroad',
#  'faa_routes',
#  'facebook_friends',
#  'facebook_organizations',
#  'facebook_wall',
#  'faculty_hiring',
#  'faculty_hiring_us',
#  'fao_trade',
#  'fediverse',
#  'flickr_aminer',
#  'flickr_groups',
#  'flickr_growth',
#  'flixster',
#  'florentine_families',
#  'fly_hemibrain',
#  'foldoc',
#  'foodweb_baywet',
#  'foodweb_little_rock',
#  'football',
#  'football_tsevans',
#  'foursquare',
#  'foursquare_friendships',
#  'foursquare_global',
#  'fresh_webs',
#  'freshmen',
#  'fullerene_structures',
#  'game_thrones',
#  'genetic_multiplex',
#  'github',
#  'gnutella',
#  'google',
#  'google_plus',
#  'google_web',
#  'hens',
#  'high_tech_company',
#  'highschool',
#  'hiv_transmission',
#  'human_brains',
#  'hyves',
#  'inploid',
#  'interactome_figeys',
#  'interactome_pdz',
#  'interactome_stelzl',
#  'interactome_vidal',
#  'interactome_yeast',
#  'internet_as',
#  'internet_top_pop',
#  'jazz_collab',
#  'jdk',
#  'jester',
#  'jung',
#  'kangaroo',
#  'karate',
#  'kegg_metabolic',
#  'kidnappings',
#  'lastfm',
#  'lastfm_aminer',
#  'law_firm',
#  'lesmis',
#  'libimseti',
#  'linux',
#  'livejournal',
#  'livejournal_aminer',
#  'livemocha',
#  'lkml_reply',
#  'lkml_thread',
#  'london_transport',
#  'macaque_neural',
#  'macaques',
#  'mag_geology_coauthor',
#  'mag_history_coauthor',
#  'malaria_genes',
#  'marker_cafe',
#  'marvel_partnerships',
#  'marvel_universe',
#  'messal_shale',
#  'microsoft_concept',
#  'mislove_osn',
#  'montreal',
#  'moreno_sheep',
#  'moreno_sociograms',
#  'moreno_taro',
#  'moviegalaxies',
#  'movielens_100k',
#  'myspace_aminer',
#  'nematode_mammal',
#  'netscience',
#  'new_guinea_tribes',
#  'new_zealand_collab',
#  'notre_dame_web',
#  'november17',
#  'openflights',
#  'openstreetmap',
#  'packet_delays',
#  'paris_transportation',
#  'petster',
#  'pgp_strong',
#  'physician_trust',
#  'physics_collab',
#  'plant_pol_kato',
#  'plant_pol_robertson',
#  'plant_pol_vazquez',
#  'pokec',
#  'polblogs',
#  'polbooks',
#  'power',
#  'product_space',
#  'prosper',
#  'python_dependency',
#  'qa_user',
#  'reactome',
#  'reality_mining',
#  'residence_hall',
#  'reuters',
#  'revolution',
#  'rhesus_monkey',
#  'roadnet',
#  'route_views',
#  'sa_companies',
#  'scotus_majority',
#  'slashdot_threads',
#  'slashdot_zoo',
#  'soc_net_comms',
#  'social_location',
#  'software_dependencies',
#  'sp_baboons',
#  'sp_colocation',
#  'sp_high_school',
#  'sp_high_school_new',
#  'sp_hospital',
#  'sp_hypertext',
#  'sp_infectious',
#  'sp_kenyan_households',
#  'sp_office',
#  'sp_primary_school',
#  'stackoverflow',
#  'stanford_web',
#  'student_cooperation',
#  'swingers',
#  'terrorists_911',
#  'topology',
#  'trackers',
#  'train_terrorists',
#  'trec',
#  'trec_web',
#  'tree-of-life',
#  'twitter',
#  'twitter_15m',
#  'twitter_2009',
#  'twitter_events',
#  'twitter_higgs',
#  'twitter_sample',
#  'twitter_social',
#  'ugandan_village',
#  'un_migrations',
#  'uni_email',
#  'unicodelang',
#  'urban_streets',
#  'us_agencies',
#  'us_air_traffic',
#  'us_congress',
#  'us_patents',
#  'us_roads',
#  'visualizeus',
#  'webkb',
#  'wiki_article_words',
#  'wiki_categories',
#  'wiki_link_dyn',
#  'wiki_rfa',
#  'wiki_science',
#  'wiki_talk',
#  'wiki_users',
#  'wikiconflict',
#  'wikipedia-en-talk',
#  'wikipedia_growth',
#  'wikipedia_link',
#  'wikitree',
#  'windsurfers',
#  'word_adjacency',
#  'word_assoc',
#  'wordnet',
#  'yahoo_ads',
#  'yahoo_song',
#  'yeast_transcription',
#  'zebras']

# %%
list(filter(lambda s: "uganda" in s, list(get_all_netzschleuder_network_keys())))
# Out:
# ['ugandan_village']

# %%
get_netzschleuder_network_info("ugandan_village")
# Out:
# {'title': 'Ugandan village networks (2013)',
#  'description': 'Complete friendship and health advice social networks among households in 17 rural villages bordering Lake Victoria in Mayuge District, Uganda in 2013. Nodes are households and edges represent either a close friendship or a trusted health advisor connection, obtained via a name generator questionnaire.[^icon]\n[^icon]: Description obtained from the [ICON](https://icon.colorado.edu) project.',
#  'citation': [['G. F. Chami et al., "Social network fragmentation and community health." Proc. Natl. Acad. Sci. USA 114(36), E7425–E7431 (2017)',
#    'https://doi.org/10.1073/pnas.1700166114']],
#  'bibtex': ['@article{chami_social_2017,\n  doi          = {10.1073/pnas.1700166114},\n  url          = {https://doi.org/10.1073%2Fpnas.1700166114},\n  year         = 2017,\n  month        = jul,\n  publisher    = {Proceedings of the National Academy of Sciences},\n  volume       = 114,\n  number       = 36,\n  author       = {Goylette F. Chami and Sebastian E. Ahnert and Narcis\n    B. Kabatereine and Edridah M. Tukahebwa},\n  title        = {Social network fragmentation and community health},\n  journal      = {Proceedings of the National Academy of Sciences},\n}'],
#  'url': 'https://www.repository.cam.ac.uk/handle/1810/270256?show=full',
#  'restricted': False,
#  'tags': ['Social', 'Offline', 'Unweighted', 'Multilayer'],
#  'nets': ['friendship-1',
#   'friendship-2',
#   'friendship-3',
#   'friendship-4',
#   'friendship-5',
#   'friendship-6',
#   'friendship-7',
#   'friendship-8',
#   'friendship-9',
#   'friendship-10',
#   'friendship-11',
#   'friendship-12',
#   'friendship-13',
#   'friendship-14',
#   'friendship-15',
#   'friendship-16',
#   'friendship-17',
#   'health-advice_1',
#   'health-advice_2',
#   'health-advice_3',
#   'health-advice_4',
#   'health-advice_5',
#   'health-advice_6',
#   'health-advice_7',
#   'health-advice_8',
#   'health-advice_9',
#   'health-advice_10',
#   'health-advice_11',
#   'health-advice_12',
#   'health-advice_13',
#   'health-advice_14',
#   'health-advice_15',
#   'health-advice_16',
#   'health-advice_17'],
#  'analyses': {'friendship-1': {'num_edges': 600,
#    'num_vertices': 203,
#    'is_directed': False,
#    'average_degree': 5.911330049261084,
#    'degree_std_dev': 4.372103652613415,
#    'is_bipartite': False,
#    'global_clustering': 0.060486522024983565,
#    'degree_assortativity': -0.08281963504670645,
#    'largest_component_fraction': 0.9950738916256158,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7827938275544106,
#    'mixing_time': 4.083533936834301,
#    'hashimoto_radius': 7.102407188159695,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.470892790853785,
#    'knn_proj_2': 1.446787674930033},
#   'friendship-2': {'num_edges': 775,
#    'num_vertices': 182,
#    'is_directed': False,
#    'average_degree': 8.516483516483516,
#    'degree_std_dev': 6.98092005234273,
#    'is_bipartite': False,
#    'global_clustering': 0.10925397472482674,
#    'degree_assortativity': -0.046914859424423375,
#    'largest_component_fraction': 0.9945054945054945,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6942383823225902,
#    'mixing_time': 2.7401773152601234,
#    'hashimoto_radius': 11.040537647256931,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5082949010278788,
#    'knn_proj_2': 1.4941562969600457},
#   'friendship-3': {'num_edges': 1181,
#    'num_vertices': 192,
#    'is_directed': False,
#    'average_degree': 12.302083333333334,
#    'degree_std_dev': 9.420301427929763,
#    'is_bipartite': False,
#    'global_clustering': 0.13999623918766455,
#    'degree_assortativity': -0.0674507262088725,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6105233541823709,
#    'mixing_time': 2.0265940535299203,
#    'hashimoto_radius': 15.70523354949838,
#    'diameter': 4,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5337114249856354,
#    'knn_proj_2': 1.514931174758429},
#   'friendship-4': {'num_edges': 2302,
#    'num_vertices': 320,
#    'is_directed': False,
#    'average_degree': 14.3875,
#    'degree_std_dev': 9.984667933887435,
#    'is_bipartite': False,
#    'global_clustering': 0.09441822331538478,
#    'degree_assortativity': -0.08879904298085196,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6381918643224109,
#    'mixing_time': 2.2265946947395605,
#    'hashimoto_radius': 17.23038120491907,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5147204483641326,
#    'knn_proj_2': 1.4997902940353558},
#   'friendship-5': {'num_edges': 822,
#    'num_vertices': 184,
#    'is_directed': False,
#    'average_degree': 8.934782608695652,
#    'degree_std_dev': 6.578628685943874,
#    'is_bipartite': False,
#    'global_clustering': 0.12454996594336869,
#    'degree_assortativity': -0.0183553566679158,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7167501604518655,
#    'mixing_time': 3.00275096707002,
#    'hashimoto_radius': 10.630307383144956,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.493391780894271,
#    'knn_proj_2': 1.5135140670465517},
#   'friendship-6': {'num_edges': 709,
#    'num_vertices': 139,
#    'is_directed': False,
#    'average_degree': 10.201438848920864,
#    'degree_std_dev': 7.184295278532073,
#    'is_bipartite': False,
#    'global_clustering': 0.1360749924402782,
#    'degree_assortativity': -0.06051071411119073,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6783378059721014,
#    'mixing_time': 2.5765899330560647,
#    'hashimoto_radius': 12.044983893719571,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5239528074377606,
#    'knn_proj_2': 1.5171251128733272},
#   'friendship-7': {'num_edges': 929,
#    'num_vertices': 121,
#    'is_directed': False,
#    'average_degree': 15.355371900826446,
#    'degree_std_dev': 8.13609395605101,
#    'is_bipartite': False,
#    'global_clustering': 0.17981375788525084,
#    'degree_assortativity': -0.05315773888067557,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6764968377428688,
#    'mixing_time': 2.558673545512082,
#    'hashimoto_radius': 15.16033334191193,
#    'diameter': 4,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5626786874519,
#    'knn_proj_2': 1.5423335517007106},
#   'friendship-8': {'num_edges': 1902,
#    'num_vertices': 369,
#    'is_directed': False,
#    'average_degree': 10.308943089430894,
#    'degree_std_dev': 7.588820133845673,
#    'is_bipartite': False,
#    'global_clustering': 0.060009479018557,
#    'degree_assortativity': -0.04471078123987676,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6469398689874981,
#    'mixing_time': 2.296201091228909,
#    'hashimoto_radius': 12.777659354005799,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.511553932055186,
#    'knn_proj_2': 1.482803843196352},
#   'friendship-9': {'num_edges': 1248,
#    'num_vertices': 178,
#    'is_directed': False,
#    'average_degree': 14.02247191011236,
#    'degree_std_dev': 11.594727131780504,
#    'is_bipartite': False,
#    'global_clustering': 0.16776883266244969,
#    'degree_assortativity': -0.10887898757245042,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6774029625693586,
#    'mixing_time': 2.5674668332972406,
#    'hashimoto_radius': 16.859809992818768,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5412584932256195,
#    'knn_proj_2': 1.5104499657101622},
#   'friendship-10': {'num_edges': 1180,
#    'num_vertices': 207,
#    'is_directed': False,
#    'average_degree': 11.400966183574878,
#    'degree_std_dev': 7.623292493304319,
#    'is_bipartite': False,
#    'global_clustering': 0.10375560538116592,
#    'degree_assortativity': -0.021879451181927797,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6408244117382421,
#    'mixing_time': 2.2471920806354815,
#    'hashimoto_radius': 14.010747595925189,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5257355938209685,
#    'knn_proj_2': 1.4932291479315103},
#   'friendship-11': {'num_edges': 1183,
#    'num_vertices': 250,
#    'is_directed': False,
#    'average_degree': 9.464,
#    'degree_std_dev': 6.847532694335968,
#    'is_bipartite': False,
#    'global_clustering': 0.10292224510813594,
#    'degree_assortativity': -0.11604901044544795,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7360396825079685,
#    'mixing_time': 3.262948858924127,
#    'hashimoto_radius': 11.09582436999828,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.484666981326531,
#    'knn_proj_2': 1.4640279857609055},
#   'friendship-12': {'num_edges': 962,
#    'num_vertices': 229,
#    'is_directed': False,
#    'average_degree': 8.40174672489083,
#    'degree_std_dev': 7.955399501497593,
#    'is_bipartite': False,
#    'global_clustering': 0.08997188378631678,
#    'degree_assortativity': -0.05915618043756488,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7619611580299009,
#    'mixing_time': 3.678367945749566,
#    'hashimoto_radius': 11.898284518549136,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.475110841204829,
#    'knn_proj_2': 1.472239034852804},
#   'friendship-13': {'num_edges': 873,
#    'num_vertices': 183,
#    'is_directed': False,
#    'average_degree': 9.540983606557377,
#    'degree_std_dev': 6.559289338651448,
#    'is_bipartite': False,
#    'global_clustering': 0.09783956082875864,
#    'degree_assortativity': -0.07947718400150909,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6434303952384528,
#    'mixing_time': 2.267874929055142,
#    'hashimoto_radius': 11.668082302192033,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.524360136353083,
#    'knn_proj_2': 1.5026624399014148},
#   'friendship-14': {'num_edges': 603,
#    'num_vertices': 124,
#    'is_directed': False,
#    'average_degree': 9.725806451612904,
#    'degree_std_dev': 6.387157868720514,
#    'is_bipartite': False,
#    'global_clustering': 0.15182540751717635,
#    'degree_assortativity': -0.04549584601931837,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7790998842568752,
#    'mixing_time': 4.0061531274204505,
#    'hashimoto_radius': 10.988597006263877,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.43564593676051,
#    'knn_proj_2': 1.5321272424406756},
#   'friendship-15': {'num_edges': 295,
#    'num_vertices': 120,
#    'is_directed': False,
#    'average_degree': 4.916666666666667,
#    'degree_std_dev': 3.597645835203287,
#    'is_bipartite': False,
#    'global_clustering': 0.07115697990222705,
#    'degree_assortativity': -0.04165340995988925,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.808511717689237,
#    'mixing_time': 4.704551641222215,
#    'hashimoto_radius': 5.8469106263428365,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.463707343995023,
#    'knn_proj_2': 1.435832956463808},
#   'friendship-16': {'num_edges': 1475,
#    'num_vertices': 372,
#    'is_directed': False,
#    'average_degree': 7.93010752688172,
#    'degree_std_dev': 6.0562290859185754,
#    'is_bipartite': False,
#    'global_clustering': 0.0558420771829984,
#    'degree_assortativity': -0.03794332520108542,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.8725783546507067,
#    'mixing_time': 7.3366051364843,
#    'hashimoto_radius': 9.931830485044925,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.266745571889747,
#    'knn_proj_2': 1.5085302961525473},
#   'friendship-17': {'num_edges': 300,
#    'num_vertices': 65,
#    'is_directed': False,
#    'average_degree': 9.23076923076923,
#    'degree_std_dev': 6.985191436767072,
#    'is_bipartite': False,
#    'global_clustering': 0.27473344904537567,
#    'degree_assortativity': -0.07498152424125659,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.6703141802205121,
#    'mixing_time': 2.4999453086579417,
#    'hashimoto_radius': 10.201871443455003,
#    'diameter': 4,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.720428262639186,
#    'knn_proj_2': 1.63176001767762},
#   'health-advice_1': {'num_edges': 473,
#    'num_vertices': 190,
#    'is_directed': False,
#    'average_degree': 4.978947368421053,
#    'degree_std_dev': 6.331174244405171,
#    'is_bipartite': False,
#    'global_clustering': 0.05538977993286087,
#    'degree_assortativity': -0.1851445851259659,
#    'largest_component_fraction': 0.9842105263157894,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.849968050252796,
#    'mixing_time': 6.151706565994506,
#    'hashimoto_radius': 8.691374405022646,
#    'diameter': 8,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4106596322401717,
#    'knn_proj_2': 1.3943377089210587},
#   'health-advice_2': {'num_edges': 432,
#    'num_vertices': 170,
#    'is_directed': False,
#    'average_degree': 5.08235294117647,
#    'degree_std_dev': 8.122172651533264,
#    'is_bipartite': False,
#    'global_clustering': 0.057039187227866474,
#    'degree_assortativity': -0.2971226172404849,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.9096891641573077,
#    'mixing_time': 10.564981880339053,
#    'hashimoto_radius': 9.711731959531885,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4533549794077123,
#    'knn_proj_2': 1.2950007854951406},
#   'health-advice_3': {'num_edges': 682,
#    'num_vertices': 185,
#    'is_directed': False,
#    'average_degree': 7.372972972972973,
#    'degree_std_dev': 10.36503083132919,
#    'is_bipartite': False,
#    'global_clustering': 0.08368500107288462,
#    'degree_assortativity': -0.3476090535166664,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.8652716778250454,
#    'mixing_time': 6.91028923845528,
#    'hashimoto_radius': 13.001834605008982,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.5161016335182427,
#    'knn_proj_2': 1.3226855591873958},
#   'health-advice_4': {'num_edges': 1118,
#    'num_vertices': 316,
#    'is_directed': False,
#    'average_degree': 7.075949367088608,
#    'degree_std_dev': 6.7655533924651765,
#    'is_bipartite': False,
#    'global_clustering': 0.0548330671533957,
#    'degree_assortativity': -0.09975820679167549,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.8585900635159333,
#    'mixing_time': 6.558938457189267,
#    'hashimoto_radius': 10.45006119526057,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4414615570171945,
#    'knn_proj_2': 1.4072336260696379},
#   'health-advice_5': {'num_edges': 423,
#    'num_vertices': 168,
#    'is_directed': False,
#    'average_degree': 5.035714285714286,
#    'degree_std_dev': 7.178749109385994,
#    'is_bipartite': False,
#    'global_clustering': 0.08868243243243243,
#    'degree_assortativity': -0.18764768293273987,
#    'largest_component_fraction': 0.9880952380952381,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.8692193131980689,
#    'mixing_time': 7.134712800072668,
#    'hashimoto_radius': 9.029017608033191,
#    'diameter': 8,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4308571926736207,
#    'knn_proj_2': 1.4032028364648337},
#   'health-advice_6': {'num_edges': 322,
#    'num_vertices': 134,
#    'is_directed': False,
#    'average_degree': 4.8059701492537314,
#    'degree_std_dev': 9.048358977086034,
#    'is_bipartite': False,
#    'global_clustering': 0.06434699714013346,
#    'degree_assortativity': -0.300764613749088,
#    'largest_component_fraction': 0.9776119402985075,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.8638536839966289,
#    'mixing_time': 6.832847356690627,
#    'hashimoto_radius': 9.304934578746964,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4847477485006735,
#    'knn_proj_2': 1.3097328164687296},
#   'health-advice_7': {'num_edges': 577,
#    'num_vertices': 121,
#    'is_directed': False,
#    'average_degree': 9.537190082644628,
#    'degree_std_dev': 7.8055302733488965,
#    'is_bipartite': False,
#    'global_clustering': 0.13954429014426317,
#    'degree_assortativity': -0.07053087924320857,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7510013178403918,
#    'mixing_time': 3.4922557359457245,
#    'hashimoto_radius': 11.91739791163239,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4667276551273365,
#    'knn_proj_2': 1.500060365990584},
#   'health-advice_8': {'num_edges': 1360,
#    'num_vertices': 361,
#    'is_directed': False,
#    'average_degree': 7.534626038781163,
#    'degree_std_dev': 7.5957082893525945,
#    'is_bipartite': False,
#    'global_clustering': 0.04867111451383572,
#    'degree_assortativity': -0.13949307848112863,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7899318393255161,
#    'mixing_time': 4.240727139284364,
#    'hashimoto_radius': 11.15484464158005,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.45486240895391,
#    'knn_proj_2': 1.4157970079279125},
#   'health-advice_9': {'num_edges': 678,
#    'num_vertices': 173,
#    'is_directed': False,
#    'average_degree': 7.838150289017341,
#    'degree_std_dev': 10.845597441441678,
#    'is_bipartite': False,
#    'global_clustering': 0.10157246068848279,
#    'degree_assortativity': -0.23082859505443717,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7839198896020036,
#    'mixing_time': 4.107645863242777,
#    'hashimoto_radius': 13.770885619176706,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.491792133132643,
#    'knn_proj_2': 1.4162386154852675},
#   'health-advice_10': {'num_edges': 884,
#    'num_vertices': 205,
#    'is_directed': False,
#    'average_degree': 8.62439024390244,
#    'degree_std_dev': 8.608016130408227,
#    'is_bipartite': False,
#    'global_clustering': 0.13321786822544562,
#    'degree_assortativity': -0.08386460614169007,
#    'largest_component_fraction': 0.9951219512195122,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7574444218217665,
#    'mixing_time': 3.599645746761275,
#    'hashimoto_radius': 13.811560121801524,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.469665595828413,
#    'knn_proj_2': 1.4886634985110019},
#   'health-advice_11': {'num_edges': 588,
#    'num_vertices': 240,
#    'is_directed': False,
#    'average_degree': 4.9,
#    'degree_std_dev': 7.708653146518744,
#    'is_bipartite': False,
#    'global_clustering': 0.05260796410544027,
#    'degree_assortativity': -0.21475911173581494,
#    'largest_component_fraction': 0.975,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.9300380576229443,
#    'mixing_time': 13.787441754763046,
#    'hashimoto_radius': 9.711735794461495,
#    'diameter': 8,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.20396396275828,
#    'knn_proj_2': 1.395785999030644},
#   'health-advice_12': {'num_edges': 579,
#    'num_vertices': 221,
#    'is_directed': False,
#    'average_degree': 5.239819004524887,
#    'degree_std_dev': 7.520797587179908,
#    'is_bipartite': False,
#    'global_clustering': 0.041495281877570775,
#    'degree_assortativity': -0.11090831470467191,
#    'largest_component_fraction': 0.9864253393665159,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.9078249090976712,
#    'mixing_time': 10.340860579047561,
#    'hashimoto_radius': 8.205424420460854,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.241719093022691,
#    'knn_proj_2': 1.4455648075782617},
#   'health-advice_13': {'num_edges': 358,
#    'num_vertices': 173,
#    'is_directed': False,
#    'average_degree': 4.138728323699422,
#    'degree_std_dev': 4.553262515922923,
#    'is_bipartite': False,
#    'global_clustering': 0.05946163117717959,
#    'degree_assortativity': -0.11259356720937941,
#    'largest_component_fraction': 0.9075144508670521,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.919909534784706,
#    'mixing_time': 11.97892492208626,
#    'hashimoto_radius': 6.555303276588678,
#    'diameter': 8,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.372430838541761,
#    'knn_proj_2': 1.276472812141111},
#   'health-advice_14': {'num_edges': 365,
#    'num_vertices': 120,
#    'is_directed': False,
#    'average_degree': 6.083333333333333,
#    'degree_std_dev': 4.879520695951829,
#    'is_bipartite': False,
#    'global_clustering': 0.10579427083333333,
#    'degree_assortativity': -0.15643122133702314,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7830567520270313,
#    'mixing_time': 4.089141562421632,
#    'hashimoto_radius': 7.420817262813932,
#    'diameter': 6,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4853106595108247,
#    'knn_proj_2': 1.4434601645433767},
#   'health-advice_15': {'num_edges': 210,
#    'num_vertices': 117,
#    'is_directed': False,
#    'average_degree': 3.58974358974359,
#    'degree_std_dev': 4.809452669170248,
#    'is_bipartite': False,
#    'global_clustering': 0.06208425720620843,
#    'degree_assortativity': -0.2588914628115707,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.9138984140794855,
#    'mixing_time': 11.106685955903895,
#    'hashimoto_radius': 5.928131265369937,
#    'diameter': 8,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4320974381266423,
#    'knn_proj_2': 1.3075260000448865},
#   'health-advice_16': {'num_edges': 984,
#    'num_vertices': 350,
#    'is_directed': False,
#    'average_degree': 5.622857142857143,
#    'degree_std_dev': 12.538422906394244,
#    'is_bipartite': False,
#    'global_clustering': 0.049861142145752865,
#    'degree_assortativity': -0.19709295756326103,
#    'largest_component_fraction': 0.9971428571428571,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.8278081197094427,
#    'mixing_time': 5.2917363084269455,
#    'hashimoto_radius': 12.830473447331471,
#    'diameter': 7,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.4330290855467562,
#    'knn_proj_2': 1.3934548315725144},
#   'health-advice_17': {'num_edges': 159,
#    'num_vertices': 63,
#    'is_directed': False,
#    'average_degree': 5.0476190476190474,
#    'degree_std_dev': 4.732288856687559,
#    'is_bipartite': False,
#    'global_clustering': 0.12403697996918336,
#    'degree_assortativity': -0.26973222160299126,
#    'largest_component_fraction': 1.0,
#    'edge_reciprocity': 1.0,
#    'transition_gap': 0.7677522721107659,
#    'mixing_time': 3.783748765551677,
#    'hashimoto_radius': 6.311096505134261,
#    'diameter': 5,
#    'edge_properties': [],
#    'vertex_properties': [['name', 'string'], ['_pos', 'vector<double>']],
#    'knn_proj_1': 3.531112252304253,
#    'knn_proj_2': 1.4204078297691622}}}
